# %% [markdown]
# 檢查是否有連結GPU
#
# https://colab.research.google.com/notebooks/gpu.ipynb

# %%
import tensorflow as tf
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/
# Out:
# /content/drive/MyDrive

# %%
from PTTScraper import PTTScraper

board = "Gossiping"
scraper = PTTScraper(board)
data = scraper.get_data_days_before(1, max_posts=300)
# Out:
# 2023-06-27 00:00:00
# 文章總篇數: 7
# 2023-06-27 00:00:00
# 文章總篇數: 26
# 2023-06-27 00:00:00
# 文章總篇數: 46
# 2023-06-27 00:00:00
# 文章總篇數: 65
# 2023-06-27 00:00:00
# 文章總篇數: 83
# 2023-06-27 00:00:00
# 文章總篇數: 102
# 2023-06-27 00:00:00
# 文章總篇數: 120
# 2023-06-27 00:00:00
# 文章總篇數: 140
# 2023-06-27 00:00:00
# 文章總篇數: 160
# 2023-06-27 00:00:00
# 文章總篇數: 180
# 2023-06-27 00:00:00
# 文章總篇數: 199
# 2023-06-27 00:00:00
# 文章總篇數: 219
# 2023-06-27 00:00:00
# 文章總篇數: 238
# 2023-06-27 00:00:00
# 文章總篇數: 257
# 2023-06-27 00:00:00
# 文章總篇數: 276
# 2023-06-27 00:00:00
# 文章總篇數: 296
# 2023-06-27 00:00:00
# 文章總篇數: 300

# %%
import pandas as pd
df0626 = pd.DataFrame(data)

# %%
# !pip install -U ckiptagger[tf,gdown]
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting ckiptagger[gdown,tf]
#   Downloading ckiptagger-0.2.1-py3-none-any.whl (34 kB)
# Requirement already satisfied: tensorflow>=1.13.1 in /usr/local/lib/python3.10/dist-packages (from ckiptagger[gdown,tf]) (2.12.0)
# Requirement already satisfied: gdown in /usr/local/lib/python3.10/dist-packages (from ckiptagger[gdown,tf]) (4.6.6)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=1.13.1->ckiptagger[gdown,tf]) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=1.13.1->ckiptagger[gdown,tf]) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=1.13.1->ckiptagger[gdown,tf]) (23.5.26)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=1.13.1->ckiptagger[gdown,tf]) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=1.13.1->ckiptagger[gdown,tf]) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=1.13.1->ckiptagger[gdown,tf]) (1.56.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=1.13.1->ckiptagger[gdown,tf]) (3.8.0)
# Requirement already satisfied: jax>=0.3.15 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=1.13.1->ckiptagger[gdown,tf]) (0.4.10)
# Requirement already satisfied: keras<2.13,>=2.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=1.13.1->ckiptagger[gdown,tf]) (2.12.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=1.13.1->ckiptagger[gdown,tf]) (16.0.0)
# Requirement already satisfied: numpy<1.24,>=1.22 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=1.13.1->ckiptagger[gdown,tf]) (1.22.4)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=1.13.1->ckiptagger[gdown,tf]) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow>=1.13.1->ckiptagger[gdown,tf]) (23.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=1.13.1->ckiptagger[gdown,tf]) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow>=1.13.1->ckiptagger[gdown,tf]) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=1.13.1->ckiptagger[gdown,tf]) (1.16.0)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=1.13.1->ckiptagger[gdown,tf]) (2.12.3)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=1.13.1->ckiptagger[gdown,tf]) (2.12.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=1.13.1->ckiptagger[gdown,tf]) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=1.13.1->ckiptagger[gdown,tf]) (4.6.3)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=1.13.1->ckiptagger[gdown,tf]) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=1.13.1->ckiptagger[gdown,tf]) (0.32.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from gdown->ckiptagger[gdown,tf]) (3.12.2)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.10/dist-packages (from gdown->ckiptagger[gdown,tf]) (2.27.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from gdown->ckiptagger[gdown,tf]) (4.65.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from gdown->ckiptagger[gdown,tf]) (4.11.2)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow>=1.13.1->ckiptagger[gdown,tf]) (0.40.0)
# Requirement already satisfied: ml-dtypes>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from jax>=0.3.15->tensorflow>=1.13.1->ckiptagger[gdown,tf]) (0.2.0)
# Requirement already satisfied: scipy>=1.7 in /usr/local/lib/python3.10/dist-packages (from jax>=0.3.15->tensorflow>=1.13.1->ckiptagger[gdown,tf]) (1.10.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow>=1.13.1->ckiptagger[gdown,tf]) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow>=1.13.1->ckiptagger[gdown,tf]) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow>=1.13.1->ckiptagger[gdown,tf]) (3.4.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow>=1.13.1->ckiptagger[gdown,tf]) (0.7.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow>=1.13.1->ckiptagger[gdown,tf]) (2.3.6)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->gdown->ckiptagger[gdown,tf]) (2.4.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown->ckiptagger[gdown,tf]) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown->ckiptagger[gdown,tf]) (2023.5.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown->ckiptagger[gdown,tf]) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown->ckiptagger[gdown,tf]) (3.4)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown->ckiptagger[gdown,tf]) (1.7.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow>=1.13.1->ckiptagger[gdown,tf]) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow>=1.13.1->ckiptagger[gdown,tf]) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow>=1.13.1->ckiptagger[gdown,tf]) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow>=1.13.1->ckiptagger[gdown,tf]) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow>=1.13.1->ckiptagger[gdown,tf]) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow>=1.13.1->ckiptagger[gdown,tf]) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow>=1.13.1->ckiptagger[gdown,tf]) (3.2.2)
# Installing collected packages: ckiptagger
# Successfully installed ckiptagger-0.2.1

# %%
from ckiptagger import data_utils, construct_dictionary, WS, POS, NER

# %%
data_utils.download_data_gdown("./")
# data_utils.download_data_url("./")
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1efHsY16pxK0lBD2gYCgCTnv1Swstq771
# To: /content/drive/MyDrive/data.zip
# 100%|██████████| 1.88G/1.88G [00:47<00:00, 39.8MB/s]

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

# %%
ws = WS("./data", disable_cuda=False)
pos = POS("./data", disable_cuda=False)
ner = NER("./data", disable_cuda=False)
# Out:
# /usr/local/lib/python3.10/dist-packages/ckiptagger/model_ws.py:106: UserWarning: `tf.nn.rnn_cell.LSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
#   cell = tf.compat.v1.nn.rnn_cell.LSTMCell(hidden_d, name=name)
# /usr/local/lib/python3.10/dist-packages/ckiptagger/model_pos.py:56: UserWarning: `tf.nn.rnn_cell.LSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
#   cell = tf.compat.v1.nn.rnn_cell.LSTMCell(hidden_d, name=name)
# /usr/local/lib/python3.10/dist-packages/ckiptagger/model_ner.py:57: UserWarning: `tf.nn.rnn_cell.LSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
#   cell = tf.compat.v1.nn.rnn_cell.LSTMCell(hidden_d, name=name)

# %%
import pandas as pd

# df = pd.DataFrame(data)
sentence_list = list(df0626.Content)

# %%
word_sentence_list = ws(
    sentence_list,
    # sentence_segmentation = True, # To consider delimiters
    # segment_delimiter_set = {",", "。", ":", "?", "!", ";"}), # This is the defualt set of delimiters
    # recommend_dictionary = dictionary1, # words in this dictionary are encouraged
    # coerce_dictionary = dictionary2, # words in this dictionary are forced
)

pos_sentence_list = pos(word_sentence_list)

entity_sentence_list = ner(word_sentence_list, pos_sentence_list)

# %%
def print_word_pos_sentence(word_sentence, pos_sentence):
    assert len(word_sentence) == len(pos_sentence)
    for word, pos in zip(word_sentence, pos_sentence):
        print(f"{word}({pos})", end="\u3000")
    print()
    return

for i, sentence in enumerate(sentence_list):
    print()
    print(f"'{sentence}'")
    print_word_pos_sentence(word_sentence_list[i],  pos_sentence_list[i])
    for entity in sorted(entity_sentence_list[i]):
        print(entity)
# Out:
# Streaming output truncated to the last 5000 lines.
# Sent from JPTT on my Samsung SM-S(Nb)　9180(Neu)　.(PERIODCATEGORY)
#
# --
# (FW)
# (2, 13, 'PERSON', 'rubberking ')
#
# '作者wahaha99 (此方不可長)看板Gossiping標題Re: [問卦] 真的有女生婚後不跟老公做愛的嗎？？時間Tue Jun 27 15:34:44 2023
# ※ 引述《chiafann (NAZZZ)》之銘言：
# : 我剛剛看到一篇文章
# : 說有些女生  婚後  頂多做幾次
# : 生小孩之後  直接關機到小孩上幼稚園
# : 這會不會太誇大  不太可能吧
# : 不管男女  應該都有性慾問題呀
# : 真的有女生婚後不跟老公做愛的嗎？？
#
# 很多
# 非常多
# 甚至婚前就不怎麼想做的就很多
# 這也是我覺得奇怪的地方
#
# 雖說生理上可能平均而言
# 女性慾望比男性低
#
# 但是台灣如此還是全球如此
# 總覺得台灣特別嚴重
# 才會導致現在的男女市場嚴重失衡
#
# 至於說"不是不想做 是不想跟你做"的
# 我相信有一部分是這樣
# 但確實很多也沒有劈腿 花心什麼的
# 好像在性方面無欲無求
#
# 這到底是啥造成的
# 飲食? 文化? 基因?
#
# --
# '
# 作者(Na)　wahaha(FW)　99(Neu)　 (WHITESPACE)　((PARENTHESISCATEGORY)　此(Nep)　方(Ncd)　不可(D)　長(VH)　)(PARENTHESISCATEGORY)　看板(Na)　Gossiping(FW)　標題(Na)　Re: [(FW)　問卦(Na)　] (FW)　真的(D)　有(V_2)　女生(Na)　婚後(Nd)　不(D)　跟(P)　老公(Na)　做愛(VA)　的(T)　嗎(T)　？(QUESTIONCATEGORY)　？(QUESTIONCATEGORY)　時間(Na)　Tue Jun (FW)　27(Neu)　 (WHITESPACE)　15:34:44(Nd)　 (WHITESPACE)　2023
# (Nd)　※ (FW)　引述(VC)　《(PARENTHESISCATEGORY)　chiafann (FW)　((PARENTHESISCATEGORY)　NAZZZ(FW)　)(PARENTHESISCATEGORY)　》(PARENTHESISCATEGORY)　之(DE)　銘言(Na)　：(COLONCATEGORY)
# (WHITESPACE)　:(COLONCATEGORY)　 (WHITESPACE)　我(Nh)　剛剛(D)　看到(VE)　一(Neu)　篇(Nf)　文章
# (Nb)　:(COLONCATEGORY)　 (WHITESPACE)　說(VE)　有些(Neqa)　女生(Na)　  (WHITESPACE)　婚後(Nd)　  (WHITESPACE)　頂多(Da)　做(VC)　幾(Neu)　次(Nf)
# (WHITESPACE)　:(COLONCATEGORY)　 (WHITESPACE)　生(VC)　小孩(Na)　之後(Ng)　  (WHITESPACE)　直接(VH)　關機(VA)　到(P)　小孩(Na)　上(Ncd)　幼稚園
# (Nc)　:(COLONCATEGORY)　 (WHITESPACE)　這(Nep)　會不會(D)　太(Dfa)　誇大(VC)　  (WHITESPACE)　不(D)　太(Dfa)　可能(VH)　吧
# (VE)　:(COLONCATEGORY)　 (WHITESPACE)　不管(Cbb)　男女(Na)　  (WHITESPACE)　應該(D)　都(D)　有(V_2)　性慾(Na)　問題(Na)　呀(T)
# (WHITESPACE)　:(COLONCATEGORY)　 (WHITESPACE)　真的(D)　有(V_2)　女生(Na)　婚後(Nd)　不(D)　跟(P)　老公(Na)　做愛(VA)　的(T)　嗎(T)　？(QUESTIONCATEGORY)　？(QUESTIONCATEGORY)
#
# (WHITESPACE)　很多(Neqa)
# (WHITESPACE)　非常(Dfa)　多(VH)
# (WHITESPACE)　甚至(D)　婚前(Nd)　就(D)　不(D)　怎麼(D)　想(VE)　做(VC)　的(DE)　就(D)　很多(Neqa)
# (WHITESPACE)　這(Nep)　也(D)　是(SHI)　我(Nh)　覺得(VK)　奇怪(VK)　的(DE)　地方(Na)
#
# (WHITESPACE)　雖說(Cbb)　生理(Na)　上(Ng)　可能(D)　平均(VH)　而(Cbb)　言
# (VE)　女性(Na)　慾望(Na)　比(P)　男性(Na)　低
#
# (VH)　但是(Cbb)　台灣(Nc)　如此(VH)　還是(D)　全球(Nc)　如此(VH)
# (WHITESPACE)　總(D)　覺得(VK)　台灣(Nc)　特別(VH)　嚴重(VH)
# (WHITESPACE)　才(Da)　會(D)　導致(VL)　現在(Nd)　的(DE)　男女(Na)　市場(Nc)　嚴重(VH)　失衡(VH)
#
# (WHITESPACE)　至於(P)　說(VE)　"(FW)　不(D)　是(SHI)　不(D)　想(VE)　做(VC)　 (WHITESPACE)　是(SHI)　不(D)　想(VE)　跟(P)　你(Nh)　做(VC)　"(FW)　的(DE)
# (WHITESPACE)　我(Nh)　相信(VK)　有(V_2)　一(Neu)　部分(Neqa)　是(SHI)　這樣(VH)
# (WHITESPACE)　但(Cbb)　確實(D)　很多(Neqa)　也(D)　沒有(VJ)　劈腿(VA)　 (WHITESPACE)　花心(VH)　什麼(Nep)　的(DE)
# (WHITESPACE)　好像(D)　在(P)　性(Na)　方面(Na)　無(D)　欲(VK)　無(D)　求(VC)
#
# (WHITESPACE)　這(Nep)　到底(D)　是(SHI)　啥(Nep)　造成(VK)　的(DE)
# (WHITESPACE)　飲食(Na)　?(QUESTIONCATEGORY)　 (WHITESPACE)　文化(Na)　?(QUESTIONCATEGORY)　 (WHITESPACE)　基因(Na)　?(QUESTIONCATEGORY)
#
# --
# (FW)
# (2, 11, 'PERSON', 'wahaha99 ')
# (292, 294, 'GPE', '台灣')
#
# '作者NTD300w (三百萬)看板Gossiping標題[問卦] 韓流是不是救了全亞洲髮型？時間Tue Jun 27 15:33:22 2023
#
# 現在看2010年的黑澀會棒棒糖
#
# 男的每隔玉米鬚澎到爆炸
#
# 女的厚瀏海，水母頭
#
# 那年代的審美觀就是那樣
#
# 實在是不忍直視
#
# 等到韓流興起
#
# 男的兩邊剃掉梳油頭旁分
#
# 女的空氣瀏海
#
# 終於有可看性了
#
# 韓流是不是救了全亞洲髮型？
#
#
#
#
# --
# '
# 作者(Na)　NTD(FW)　300(Neu)　w (FW)　((PARENTHESISCATEGORY)　三百萬(Neu)　)(PARENTHESISCATEGORY)　看板(Na)　Gossiping(FW)　標題(Na)　[(PARENTHESISCATEGORY)　問(VE)　卦(Na)　] (FW)　韓流(Na)　是(SHI)　不(D)　是(SHI)　救(VC)　了(Di)　全(Neqa)　亞洲(Nc)　髮型(Na)　？(QUESTIONCATEGORY)　時間(Na)　Tue Jun (FW)　27(Neu)　 (WHITESPACE)　15:33:22(Nd)　 (WHITESPACE)　2023
#
# (Nd)　現在(Nd)　看(VC)　2010年(Nd)　的(DE)　黑澀(Na)　會(D)　棒棒(Neqa)　糖
#
# 男(Na)　的(DE)　每隔(P)　玉米鬚澎(Na)　到(P)　爆炸(VH)
#
# (WHITESPACE)　女(Na)　的(DE)　厚瀏海(Na)　，(COMMACATEGORY)　水母頭
#
# (Nb)　那(Nep)　年代(Nd)　的(DE)　審美觀(Na)　就是(Cbb)　那樣(Dfa)
#
# (WHITESPACE)　實在(D)　是(SHI)　不忍(VK)　直視(VC)
#
# (WHITESPACE)　等到(P)　韓流(Na)　興起(VC)
#
# 男(Na)　的(DE)　兩(Neu)　邊(Ncd)　剃掉(VC)　梳油頭(Na)　旁(Ncd)　分
#
# 女(Na)　的(DE)　空氣(Na)　瀏海
#
# (Na)　終於(D)　有(V_2)　可看性(Na)　了(T)
#
# (WHITESPACE)　韓流(Na)　是(SHI)　不(D)　是(SHI)　救(VC)　了(Di)　全(Neqa)　亞洲(Nc)　髮型(Na)　？(QUESTIONCATEGORY)
#
#
#
#
# --
# (FW)
# (11, 14, 'CARDINAL', '三百萬')
# (77, 82, 'DATE', '2010年')
# (183, 185, 'LOC', '亞洲')
#
# '作者orze04 (orz)看板Gossiping標題Re: [新聞] 登革熱燒南台灣！單周暴增55例 高雄首見時間Tue Jun 27 15:33:09 2023
# 2015年
# 南台灣登革熱燒了半年
# 台南高雄都破百死，幾乎是戰後最嚴重的登革熱疫情
# 虧功德還是學公衛的
# https://i.imgur.com/KfdjuXw.png
# https://i.imgur.com/OMH2yZ6.png
#
# --
# '
# 作者(Na)　orze(FW)　04(Neu)　 (WHITESPACE)　((PARENTHESISCATEGORY)　orz(FW)　)(PARENTHESISCATEGORY)　看板(Na)　Gossiping(FW)　標題(Na)　Re: [(FW)　新聞(Na)　] (FW)　登革熱(Na)　燒(VC)　南(Ncd)　台灣(Nc)　！(EXCLAMATIONCATEGORY)　單周(Na)　暴增(VJ)　55(Neu)　例(Na)　 (WHITESPACE)　高雄(Nc)　首見(VE)　時間(Na)　Tue Jun (FW)　27(Neu)　 (WHITESPACE)　15:33:09(Nd)　 (WHITESPACE)　2023
# (Nd)　2015年(Nd)
# 南(DM)　台灣(Nc)　登革熱(Na)　燒(VC)　了(Di)　半(Neqa)　年(Nf)
# (WHITESPACE)　台南(Nc)　高雄(Nc)　都(D)　破(VC)　百(Neu)　死(VH)　，(COMMACATEGORY)　幾乎(Da)　是(SHI)　戰後(Nd)　最(Dfa)　嚴重(VH)　的(DE)　登革熱(Na)　疫情(Na)
# 虧(Na)　功德(Na)　還是(D)　學(VC)　公衛(A)　的(DE)
# https://i.imgur.com/KfdjuXw.png
# https://i.imgur.com/OMH2yZ6.png
#
# --
# (FW)
# (41, 43, 'GPE', '台灣')
# (48, 50, 'CARDINAL', '55')
# (52, 54, 'GPE', '高雄')
# (90, 92, 'GPE', '台灣')
# (100, 104, 'GPE', '台南高雄')
#
# '作者viable (隱士灰原I)看板Gossiping標題[問卦] 是不是該同情基督教天主教心有餘力不足時間Tue Jun 27 15:32:56 2023
# 如題
#
# 簡單精確說
#
# 對於基督教和天主教的
#
# 他們心有餘而力不足的時候
#
# 是否應該以同理心看待而不是對其羞辱？
#
# 畢竟人演化程度不同 有些群體其人體其有其極限
#
#
# ：）
# ----
# Sent from BePTT on my iPad Pro (9.7〃)
#
# --
# '
# 作者(Na)　viable (FW)　((PARENTHESISCATEGORY)　隱士(Na)　灰原(Na)　I(FW)　)(PARENTHESISCATEGORY)　看板(Na)　Gossiping(FW)　標題(Na)　[(PARENTHESISCATEGORY)　問(VE)　卦(Na)　] (PARENTHESISCATEGORY)　是(SHI)　不(D)　是(SHI)　該(D)　同情(VJ)　基督教(Nb)　天主教(Nb)　心有餘力(VH)　不足(VH)　時間(Na)　Tue Jun (FW)　27(Neu)　 (WHITESPACE)　15:32:56(Neu)　 (WHITESPACE)　2023(Neu)
# (WHITESPACE)　如(P)　題
#
# (Na)　簡單(VH)　精確(VH)　說
#
# (Na)　對於(P)　基督教(Nb)　和(Caa)　天主教(Nb)　的(DE)
#
# (WHITESPACE)　他們(Nh)　心(Na)　有餘(VH)　而(Cbb)　力(Na)　不足(VH)　的(DE)　時候(Na)
#
# (WHITESPACE)　是否(D)　應該(D)　以(P)　同理心(Na)　看待(VC)　而(Cbb)　不(D)　是(SHI)　對(P)　其(Nep)　羞辱(VC)　？(QUESTIONCATEGORY)
#
# (WHITESPACE)　畢竟(D)　人(Na)　演化(VH)　程度(Na)　不同(VH)　 (WHITESPACE)　有(V_2)　些(Nf)　群體(Na)　其(Nep)　人體(Na)　其(Nep)　有(V_2)　其(Nep)　極限(Na)
#
#
# (WHITESPACE)　：(COLONCATEGORY)　）(PARENTHESISCATEGORY)
# ----
# Sent from BePTT on my iPad Pro (FW)　((PARENTHESISCATEGORY)　9.7(Neu)　〃(FW)　)(PARENTHESISCATEGORY)
#
# --
# (FW)
# (2, 9, 'PERSON', 'viable ')
# (40, 46, 'ORG', '基督教天主教')
# (95, 98, 'ORG', '基督教')
# (99, 102, 'ORG', '天主教')
#
# '作者minche ()看板Gossiping標題[爆卦] 王鴻薇FB-聲援蘇宏達時間Tue Jun 27 15:32:45 2023
# https://www.facebook.com/photo?fbid=832443828244989&set=a.256671719155539
#
#
#
# 蘇宏達教授早上很氣的發了一篇
#
# 我們王鴻薇立委現在接著跟上
#
#
#
#
# ＃聲援蘇宏達教授
# ＃鄭文燦也想機密三十年嗎
# ＃教育部台大到底是誰核定機密
#
# 今天早上台大社科院長蘇宏達教授，公開發言抨擊教育部，將林智堅、陳明通、鄭文燦審
# 定報告列為機密，不願意向社會公開，也說這三個案例已損及台大和台灣高教的「國際聲
# 譽、嚴重影響社會觀感」，教育部為了這些民進黨人士遮遮掩掩，毫無風骨可言。
#
# 事實上，我曾公開質詢教育部為何要把鄭文燦等的審定報告列為機密，教育部以及教育部
# 長白紙黑字告訴我是台大校方列為機密，從蘇宏達教授說明來看顯然不是這麼一回事，如
# 今校方與教育部各執一詞成了羅生門，為護航這些人，政府機關竟然用謊言來掩飾謊言，
# 但終究還是東窗事發。
#
# 既然教育部不願意公告，那我自己來檢證，其實之前鄭文燦論文的檢舉人游智彬就已經提
# 供很多的證據，在我目前比對中，鄭文燦抄襲涉略文章有大量中國學者期刊、論文包括：
# 1、鄭文燦論文第十九頁起抄襲中國大陸學者王天成<<中國民主化戰略研究框架>>
# 2、鄭文燦論文第二十六頁起抄襲台灣東吳大學研究生陳彥羽論文<<北京市居民委員會之
# 民主管理研究：以萬壽路、文化路社區為例>>
#
# 還有其他像是國安會副秘書長徐斯儉等等族繁不及備載。
#
# 而且鄭文燦因為抄襲，在論文中更有許多中國大陸用語，鄭文燦論文早早就遭到台大撤銷
# ，如果教育部不願意昭告社會，繼續護航，不排除直接請第三方機構再幫鄭文燦審核一次
# 論文，紙包不住火，希望教育部好自為之。
#
#
#
#
#
#
# 太兇了吧！自己去檢證？？
#
# 鄭文燦不是已經被撤銷論文了嗎？
#
# 現在要繼續查喔？？？？？
#
#
#
# --
# '
# 作者(Na)　minche (FW)　((PARENTHESISCATEGORY)　)(PARENTHESISCATEGORY)　看板(Na)　Gossiping(FW)　標題(Na)　[(PARENTHESISCATEGORY)　爆卦(Na)　] (FW)　王鴻薇(Nb)　FB-(FW)　聲援(VC)　蘇宏達(Nb)　時間(Na)　Tue Jun 27(FW)　 (WHITESPACE)　15:32:45(Nd)　 (WHITESPACE)　2023
# https://www(Nd)　.(DOTCATEGORY)　facebook(FW)　.(DOTCATEGORY)　com/photo?fbid=(FW)　832443828244989(Neu)　&set=a(FW)　.(DOTCATEGORY)　256671719155539
#
#
#
# (Neu)　蘇宏達(Nb)　教授(Na)　早上(Nd)　很(Dfa)　氣(VK)　的(DE)　發(VD)　了(Di)　一(Neu)　篇(Nf)
#
# (WHITESPACE)　我們(Nh)　王鴻薇(Nb)　立委(Na)　現在(Nd)　接著(D)　跟上(VC)
#
#
#
#
# ＃(FW)　聲援(VC)　蘇宏達(Nb)　教授(Na)
# (WHITESPACE)　＃(FW)　鄭文燦(Nb)　也(D)　想(VE)　機密(Na)　三十(Neu)　年(Nf)　嗎(T)
# (WHITESPACE)　＃(FW)　教育部(Nc)　台大(Nc)　到底(D)　是(SHI)　誰(Nh)　核定(VE)　機密(Na)
#
# (162, 165, 'PERSON', '王鴻薇')
# (181, 184, 'ORG', '蘇宏達')
# (188, 191, 'PERSON', '鄭文燦')
# (195, 198, 'DATE', '三十年')
# (201, 206, 'ORG', '教育部台大')
# (218, 220, 'TIME', '早上')
# (220, 226, 'ORG', '台大社科院長')
# (226, 229, 'PERSON', '蘇宏達')
# (238, 241, 'ORG', '教育部')
# (243, 246, 'PERSON', '林智堅')
# (247, 250, 'PERSON', '陳明通')
# (251, 254, 'PERSON', '鄭文燦')
# (276, 277, 'CARDINAL', '三')
# (283, 285, 'ORG', '台大')
# (286, 288, 'GPE', '台灣')
# (308, 311, 'ORG', '教育部')
# (315, 318, 'ORG', '民進黨')
# (344, 347, 'ORG', '教育部')
# (351, 354, 'PERSON', '鄭文燦')
# (365, 368, 'ORG', '教育部')
# (383, 387, 'ORG', '台大校方')
# (393, 396, 'PERSON', '蘇宏達')
# (418, 421, 'ORG', '教育部')
# (468, 471, 'ORG', '教育部')
# (489, 492, 'PERSON', '鄭文燦')
# (498, 501, 'PERSON', '游智彬')
# (521, 524, 'PERSON', '鄭文燦')
# (533, 535, 'NORP', '中國')
# (548, 551, 'PERSON', '鄭文燦')
# (553, 556, 'ORDINAL', '第十九')
# (560, 564, 'GPE', '中國大陸')
# (566, 569, 'PERSON', '王天成')
# (571, 573, 'GPE', '中國')
# (587, 590, 'PERSON', '鄭文燦')
# (592, 596, 'ORDINAL', '第二十六')
# (600, 606, 'ORG', '台灣東吳大學')
# (609, 612, 'PERSON', '陳彥羽')
# (616, 619, 'GPE', '北京市')
# (634, 637, 'FAC', '萬壽路')
# (655, 658, 'ORG', '國安會')
# (662, 665, 'PERSON', '徐斯儉')
# (678, 681, 'PERSON', '鄭文燦')
# (694, 698, 'GPE', '中國大陸')
# (701, 704, 'PERSON', '鄭文燦')
# (711, 713, 'ORG', '台大')
# (719, 722, 'ORG', '教育部')
# (741, 743, 'ORDINAL', '第三')
# (748, 751, 'PERSON', '鄭文燦')
# (767, 770, 'ORG', '教育部')
#
# '作者chinaeatshit (我愛台灣！中國吃屎！！)看板Gossiping標題Re: [問卦] 黑人ig聲明稿時間Tue Jun 27 15:32:46 2023
# 其實這種聲明比起一些人來說
#
# 應該算是心裡坦蕩蕩才發的出來的
#
# 不然一般如果心虛的
#
# 大部份都會說  不管我是不是有意的  但如果你不舒服  我道歉
#
# 如果真的有做想賴掉的
#
# 就有可能就會說 暫停所有活動  我現在深刻的反省中
#
# 只有完全沒有做的
#
# 才會講出我要告你
#
# 而且黑人吃過這麼多人  連大欸斯吃完都能接續姐妹淘飯飯
#
# 我是不認為他會用強硬的方式吃大牙啦
#
# 希望他不會讓我翻車
#
#
# ※ 引述《GUANGLEI ()》之銘言：
# : https://i.imgur.com/sxalysd.jpg
# : 黑人陳建州已請委任律師代為聲明大牙所述全然不實  事實是如何 請大家拭目以待
# : 有卦嗎？
#
# --
# '
# (WHITESPACE)　:(COLONCATEGORY)　 (WHITESPACE)　有(V_2)　卦(Na)　嗎(T)　？(QUESTIONCATEGORY)
#
# --
# (FW)
# (18, 20, 'GPE', '台灣')
# (21, 23, 'NORP', '中國')
# (339, 342, 'PERSON', '陳建州')
#
# '作者vava5566 (開心)看板Gossiping標題Re: [問卦] 找到一個能幹的老婆是不是很難時間Tue Jun 27 15:31:25 2023
# 到底腦婆婚後不給幹的機率有多少阿？
#
# 說不給幹是指一個月小於2次那種
#
# 大家覺得比例多高？
#
# 我覺得應該至少有5%的腦婆是這種的不給幹的吧
#
# 95%應該都還算正常人吧
#
# 不給幹，又不給外食，這種最機車了啦。
#
#
# ※ 引述《Ryan1994 (健人就是腳勤)》之銘言：
# : 很多男生結婚後 才發現自己的老婆不太能幹
# : 下班通常還要做很多事
# : 我同事啦 下班後還要 煮飯洗碗曬衣服
# : 最慘的還要哄小孩入睡
# : 小孩好不容易入睡 想找老婆抱一下
# : 老婆也倒頭呼呼大睡了
# : 現在是不是很難找到能幹的老婆
#
# --
# '
# 作者(Na)　vava(FW)　5566(Neu)　 (WHITESPACE)　((PARENTHESISCATEGORY)　開心(VH)　)(PARENTHESISCATEGORY)　看板(Na)　Gossiping(FW)　標題(Na)　Re: [(FW)　問卦(Na)　] (FW)　找到(VC)　一(Neu)　個(Nf)　能幹(VH)　的(DE)　老婆(Na)　是(SHI)　不(D)　是(SHI)　很(Dfa)　難(VH)　時間(Na)　Tue Jun (FW)　27(Neu)　 (WHITESPACE)　15:31:25(Neu)　 (WHITESPACE)　2023
# (Neu)　到底(D)　腦婆(Na)　婚後(Nd)　不(D)　給幹(VA)　的(DE)　機率(Na)　有(V_2)　多少(Neqa)　阿？
#
# (Nb)　說(VE)　不(D)　給(VD)　幹(VC)　是(SHI)　指(VG)　一(Neu)　個(Nf)　月(Na)　小於(VJ)　2(Neu)　次(Nf)　那(Nep)　種(Nf)
#
# (WHITESPACE)　大家(Nh)　覺得(VK)　比例(Na)　多(Dfa)　高(VH)　？(QUESTIONCATEGORY)
#
# (WHITESPACE)　我(Nh)　覺得(VK)　應該(D)　至少(Da)　有(V_2)　5%(Neqa)　的(DE)　腦婆(Na)　是(SHI)　這(Nep)　種(Nf)　的(DE)　不(D)　給幹(VA)　的(DE)　吧
#
# (Na)　95%(Neqa)　應該(D)　都(D)　還(D)　算(VG)　正常人(Na)　吧(T)
#
# (WHITESPACE)　不(D)　給(P)　幹(VC)　，(COMMACATEGORY)　又(D)　不(D)　給(VD)　外食(VA)　，(COMMACATEGORY)　這(Nep)　種(Nf)　最(Dfa)　機車(Na)　了(T)　啦(T)　。(PERIODCATEGORY)
#
#
# (WHITESPACE)　※ (FW)　引述(VC)　《(PARENTHESISCATEGORY)　Ryan(FW)　1994(Nd)　 (WHITESPACE)　((PARENTHESISCATEGORY)　健人(Na)　就(D)　是(SHI)　腳勤(Nb)　)(PARENTHESISCATEGORY)　》(PARENTHESISCATEGORY)　之(DE)　銘言(Na)　：(COLONCATEGORY)
# (WHITESPACE)　:(COLONCATEGORY)　 (WHITESPACE)　很多(Neqa)　男生(Na)　結婚(VA)　後(Ng)　 (WHITESPACE)　才(Da)　發現(VE)　自己(Nh)　的(DE)　老婆(Na)　不(D)　太(Dfa)　能(D)　幹
# (VA)　:(COLONCATEGORY)　 (WHITESPACE)　下班(VA)　通常(D)　還要(Dfa)　做(VC)　很多(Neqa)　事(Na)
# (WHITESPACE)　:(COLONCATEGORY)　 (WHITESPACE)　我(Nh)　同事(Na)　啦(T)　 (WHITESPACE)　下班(VA)　後(Ng)　還要(Dfa)　 (WHITESPACE)　煮飯(VA)　洗(VC)　碗(Na)　曬(VJ)　衣服
# (Na)　:(COLONCATEGORY)　 (WHITESPACE)　最(Dfa)　慘(VH)　的(DE)　還(D)　要(D)　哄(VC)　小孩(Na)　入睡(VH)
# (WHITESPACE)　:(COLONCATEGORY)　 (WHITESPACE)　小孩(Na)　好不容易(D)　入睡(VH)　 (WHITESPACE)　想(VE)　找(VC)　老婆(Na)　抱(VC)　一下(Nd)
# (WHITESPACE)　:(COLONCATEGORY)　 (WHITESPACE)　老婆(Na)　也(D)　倒頭(D)　呼呼(D)　大睡(VA)　了(Di)
# (WHITESPACE)　:(COLONCATEGORY)　 (WHITESPACE)　現在(Nd)　是(SHI)　不(D)　是(SHI)　很(Dfa)　難(VH)　找到(VC)　能幹(VH)　的(DE)　老婆(Na)
#
# --
# (FW)
# (2, 6, 'PERSON', 'vava')
# (108, 109, 'CARDINAL', '2')
# (133, 135, 'PERCENT', '5%')
#
# '作者ladioshuang (達哥)看板Gossiping標題Re: [問卦] 為何大牙十幾年前事，能記那麼清楚?時間Tue Jun 27 15:31:04 2023
#
# 記憶這種東西
# 其實很可信，也很不可信
# 尤其是久遠以前的事，有時會受到個人主觀的影響而添加一些料
#
# 甚至如果有一些精神方面疾病的話
# 還會將自己的記憶扭曲，只記得對自己有利的部份
# 這都是有實際案例的
#
# 所以通常還要配合其他的事證，修正自己的記憶
#
# 不過，有指名道姓出來的就有一定的可信度，但不是絕對
# 不像之前幾個只敢用影射的，被告後又改口說影射另一個
#
# 但現在只有一個出來爆，還不夠，通常沒幾天就沒新聞性
# 要再來兩三個出來
# 就像N一樣，這樣才是百分百確定
#
# --
# '
# 作者(Na)　ladioshuang (FW)　((PARENTHESISCATEGORY)　達哥(Nb)　)(PARENTHESISCATEGORY)　看板(Na)　Gossiping(FW)　標題(Na)　Re: [(FW)　問卦(Na)　] (FW)　為何(D)　大牙(VC)　十幾(Neu)　年(Nf)　前(Ng)　事(Na)　，(COMMACATEGORY)　能(D)　記(VK)　那麼(D)　清楚(VH)　?(QUESTIONCATEGORY)　時間(Na)　Tue Jun (FW)　27(Neu)　 (WHITESPACE)　15:31:04(Nd)　 (WHITESPACE)　2023
#
# (Nd)　記憶(Na)　這(Nep)　種(Nf)　東西
# (Na)　其實(D)　很(Dfa)　可信(VH)　，(COMMACATEGORY)　也(D)　很(Dfa)　不可信
# (VH)　尤其(D)　是(SHI)　久遠(VH)　以前(Ng)　的(DE)　事(Na)　，(COMMACATEGORY)　有時(D)　會(D)　受到(VJ)　個人(Nh)　主觀(VH)　的(DE)　影響(Na)　而(Cbb)　添加(VC)　一些(Neqa)　料
#
# (Na)　甚至(D)　如果(Cbb)　有(V_2)　一些(Neqa)　精神(Na)　方面(Na)　疾病(Na)　的(DE)　話
# (Na)　還(D)　會(D)　將(P)　自己(Nh)　的(DE)　記憶(Na)　扭曲(VC)　，(COMMACATEGORY)　只(Da)　記得(VK)　對(P)　自己(Nh)　有利(VK)　的(DE)　部份(Neqa)
# (WHITESPACE)　這(Nep)　都(D)　是(SHI)　有(V_2)　實際(VH)　案例(Na)　的(DE)
#
# (WHITESPACE)　所以(Cbb)　通常(D)　還要(Dfa)　配合(VC)　其他(Neqa)　的(DE)　事證(Na)　，(COMMACATEGORY)　修正(VC)　自己(Nh)　的(DE)　記憶(Na)
#
# (WHITESPACE)　不過(Cbb)　，(COMMACATEGORY)　有(V_2)　指名道姓(VA)　出來(VA)　的(DE)　就(D)　有(V_2)　一定(A)　的(DE)　可信度(Na)　，(COMMACATEGORY)　但(Cbb)　不(D)　是(SHI)　絕對(D)
# (WHITESPACE)　不(D)　像(P)　之前(Nd)　幾(Neu)　個(Nf)　只(Da)　敢(VL)　用(P)　影射(VK)　的(T)　，(COMMACATEGORY)　被告(Na)　後(Ng)　又(D)　改口(VA)　說(VE)　影射(VK)　另(Nes)　一(Neu)　個(Nf)
#
# (WHITESPACE)　但(Cbb)　現在(Nd)　只(Da)　有(V_2)　一(Neu)　個(Nf)　出來(VA)　爆(VH)　，(COMMACATEGORY)　還(D)　不(D)　夠(VH)　，(COMMACATEGORY)　通常(D)　沒(VJ)　幾(Neu)　天(Nf)　就(D)　沒(VJ)　新聞性(Na)
# (WHITESPACE)　要(D)　再(D)　來(D)　兩三(Neu)　個(Nf)　出來(VA)
# (WHITESPACE)　就(D)　像(P)　N(FW)　一樣(VH)　，(COMMACATEGORY)　這樣(VH)　才(Da)　是(SHI)　百分百(Neqa)　確定(VK)
#
# --
# (FW)
# (2, 14, 'PERSON', 'ladioshuang ')
# (15, 17, 'PERSON', '達哥')
# (44, 48, 'DATE', '十幾年前')
# (265, 266, 'CARDINAL', '一')
# (289, 290, 'CARDINAL', '兩')
# (290, 291, 'CARDINAL', '三')
# (305, 308, 'CARDINAL', '百分百')
#
# '作者suhu5566 ()看板Gossiping標題[問卦] 代理孕母是什麼意思？？？？？？？？？時間Tue Jun 27 15:30:38 2023
# 現在社會很多什麼代理孕母啦
# 人工孕母啦 啊倆雜的
# 到底是怎麼搞啊
# 直接插入代理者嗎
# 還是自己打完後滴進去
# 還是怎麼弄啊
# 代理孕母長的不漂亮的話硬不起來算誰的
#
# --
# '
# 作者(Na)　suhu(FW)　5566(Neu)　 (WHITESPACE)　((PARENTHESISCATEGORY)　)(PARENTHESISCATEGORY)　看板(Na)　Gossiping(FW)　標題(Na)　[(PARENTHESISCATEGORY)　問卦(Na)　] (FW)　代理孕母(Na)　是(SHI)　什麼(Nep)　意思(Na)　？(QUESTIONCATEGORY)　？(QUESTIONCATEGORY)　？(QUESTIONCATEGORY)　？(QUESTIONCATEGORY)　？(QUESTIONCATEGORY)　？(QUESTIONCATEGORY)　？(QUESTIONCATEGORY)　？(QUESTIONCATEGORY)　？(QUESTIONCATEGORY)　時間(Na)　Tue Jun (FW)　27(Neu)　 (WHITESPACE)　15:30:38(Nd)　 (WHITESPACE)　2023
# (Nd)　現在(Nd)　社會(Na)　很多(Neqa)　什麼(Nep)　代理孕母(Na)　啦(T)
# (WHITESPACE)　人工(Na)　孕母(Na)　啦(T)　 (WHITESPACE)　啊倆(I)　雜(VH)　的(DE)
# (WHITESPACE)　到底(D)　是(SHI)　怎麼(D)　搞(VC)　啊(T)
# (WHITESPACE)　直接(VH)　插入(VC)　代理(VC)　者(Na)　嗎
# (FW)　還是(D)　自己(Nh)　打完(VC)　後(Ng)　滴進去(VA)
# (WHITESPACE)　還是(D)　怎麼(D)　弄(VC)　啊(T)
# (WHITESPACE)　代理孕母(Na)　長(VH)　的(DE)　不(D)　漂亮(VH)　的話(Cba)　硬(D)　不(D)　起來(Di)　算(VE)　誰(Nh)　的(DE)
#
# --
# (FW)
#
# '作者LukaDoncic77 (洞77)看板Gossiping標題[問卦] 黑人 18/22 輕鬆一下？時間Tue Jun 27 15:29:16 2023
# 汝提，被YT演算法帶回11年前
#
# https://youtu.be/_zUw6OCP2As
#
# 輕鬆一下這個用法很常見嗎？
#
# 大家怎麼看？
#
# 倒是大牙這個造型好像比短髮好看，有人贊同嗎？
#
# --
# '
# 作者(Na)　LukaDoncic(FW)　77(Neu)　 (WHITESPACE)　((PARENTHESISCATEGORY)　洞(Na)　77(Neu)　)(PARENTHESISCATEGORY)　看板(Na)　Gossiping(FW)　標題(Na)　[(PARENTHESISCATEGORY)　問卦(Na)　] (FW)　黑人(Na)　 18/22(Neu)　 (WHITESPACE)　輕鬆(VH)　一下(Nd)　？(QUESTIONCATEGORY)　時間(Na)　Tue Jun (FW)　27(Neu)　 (WHITESPACE)　15:29:16(Nd)　 (WHITESPACE)　2023
# (Nd)　汝(Nh)　提(VE)　，(COMMACATEGORY)　被(P)　YT(FW)　演算法(Na)　帶回(VC)　11(Neu)　年(Nf)　前(Ng)
#
# https://youtu.(FW)　be/_zUw6OCP2(FW)　As
#
# (FW)　輕鬆(VH)　一下(Nd)　這(Nep)　個(Nf)　用法(Na)　很(Dfa)　常見(VH)　嗎(T)　？(QUESTIONCATEGORY)
#
# (WHITESPACE)　大家(Nh)　怎麼(D)　看(VC)　？(QUESTIONCATEGORY)
#
# (WHITESPACE)　倒是(D)　大牙(Na)　這(Nep)　個(Nf)　造型(Na)　好像(D)　比(P)　短髮(Na)　好看(VH)　，(COMMACATEGORY)　有(V_2)　人(Na)　贊同(VJ)　嗎(T)　？(QUESTIONCATEGORY)
#
# --
# (FW)
# (16, 19, 'PERSON', '洞77')
#
# '作者chiafann (NAZZZ)看板Gossiping標題[問卦] 真的有女生婚後不跟老公做愛的嗎？？時間Tue Jun 27 15:29:04 2023
#
# 我剛剛看到一篇文章
#
# 說有些女生  婚後  頂多做幾次
#
# 生小孩之後  直接關機到小孩上幼稚園
#
# 這會不會太誇大  不太可能吧
#
# 不管男女  應該都有性慾問題呀
#
# 真的有女生婚後不跟老公做愛的嗎？？
#
#
#
#
# --
# '
# 作者(Na)　chiafann (FW)　((PARENTHESISCATEGORY)　NAZZZ(FW)　)(PARENTHESISCATEGORY)　看板(Na)　Gossiping(FW)　標題(Na)　[(PARENTHESISCATEGORY)　問卦(Na)　] (FW)　真的(D)　有(V_2)　女生(Na)　婚後(Nd)　不(D)　跟(P)　老公(Na)　做愛(VA)　的(T)　嗎(T)　？(QUESTIONCATEGORY)　？(QUESTIONCATEGORY)　時間(Na)　Tue Jun (FW)　27(Neu)　 (WHITESPACE)　15:29:04(Nd)　 (WHITESPACE)　2023
#
# (Nd)　我(Nh)　剛剛(D)　看到(VE)　一(Neu)　篇(Nf)　文章(Na)
#
# (WHITESPACE)　說(VE)　有些(Neqa)　女生(Na)　  (WHITESPACE)　婚後(Nd)　  (WHITESPACE)　頂多(Da)　做(VC)　幾(Neu)　次(Nf)
#
# (WHITESPACE)　生(VC)　小孩(Na)　之後(Ng)　  (WHITESPACE)　直接(VH)　關機(VA)　到(P)　小孩(Na)　上(Ncd)　幼稚園(Nc)
#
# (WHITESPACE)　這(Nep)　會不會(D)　太(Dfa)　誇大(VC)　  (WHITESPACE)　不(D)　太(Dfa)　可能(VH)　吧(T)
#
# (WHITESPACE)　不管(Cbb)　男女(Na)　  (WHITESPACE)　應該(D)　都(D)　有(V_2)　性慾(Na)　問題(Na)　呀(T)
#
# (WHITESPACE)　真的(D)　有(V_2)　女生(Na)　婚後(Nd)　不(D)　跟(P)　老公(Na)　做愛(VA)　的(T)　嗎(T)　？(QUESTIONCATEGORY)　？
#
#
#
#
# --
# (FW)
#
# '作者goodman5566 (好人56)看板Gossiping標題Re: [問卦] 為何大牙十幾年前事，能記那麼清楚?時間Tue Jun 27 15:28:54 2023
# ※ 引述《Kimmy (Kimi)》之銘言：
# : ※ 引述《kikiki37 (441)》之銘言：
# : : 阿諾內，我大概兩三年前的事就記不清楚了
# : : 但看到大牙文章，隨便就寫了幾千字，內容鉅細靡遺
# : : 什麼飯店的詳細事情，幾月幾號幾點，都寫得一清二楚
# : : 有沒有為何大牙十幾年前事，能記那麼清楚?
#
# 有的南京大屠殺
#
# 228
#
# 不是當事人
#
# 都還記得一清二楚
#
#
# 十年前的事 還是當事人
#
# 還好吧
#
# --
# '
# 作者(Na)　goodman(FW)　5566(Neu)　 (WHITESPACE)　((PARENTHESISCATEGORY)　好人(Na)　56(Neu)　)(PARENTHESISCATEGORY)　看板(Na)　Gossiping(FW)　標題(Na)　Re: [(FW)　問卦(Na)　] (FW)　為何(D)　大牙(VH)　十幾(Neu)　年(Nf)　前(Ng)　事(Na)　，(COMMACATEGORY)　能(D)　記(VK)　那麼(D)　清楚(VH)　?(QUESTIONCATEGORY)　時間(Na)　Tue Jun (FW)　27(Neu)　 (WHITESPACE)　15:28:54(Nd)　 (WHITESPACE)　2023
# (Nd)　※ (FW)　引述(VC)　《(PARENTHESISCATEGORY)　Kimmy (FW)　((PARENTHESISCATEGORY)　Kimi(FW)　)(PARENTHESISCATEGORY)　》(PARENTHESISCATEGORY)　之(DE)　銘言(Na)　：(COLONCATEGORY)
# (WHITESPACE)　:(COLONCATEGORY)　 (WHITESPACE)　※ (FW)　引述(VC)　《(PARENTHESISCATEGORY)　kikiki(FW)　37(Neu)　 (WHITESPACE)　(441)(Nd)　》(PARENTHESISCATEGORY)　之(DE)　銘言(Na)　：(COLONCATEGORY)
# (WHITESPACE)　:(COLONCATEGORY)　 (WHITESPACE)　: (PARENTHESISCATEGORY)　阿諾內(Nb)　，(COMMACATEGORY)　我(Nh)　大概(D)　兩三(Neu)　年(Nf)　前(Ng)　的(DE)　事(Na)　就(D)　記(VK)　不(D)　清楚(VH)　了(Di)
# (WHITESPACE)　:(COLONCATEGORY)　 (WHITESPACE)　: (COLONCATEGORY)　但(Cbb)　看到(VE)　大牙(Na)　文章(Na)　，(COMMACATEGORY)　隨便(VH)　就(D)　寫(VC)　了(Di)　幾千(Neu)　字(Na)　，(COMMACATEGORY)　內容(Na)　鉅細靡遺
# (VH)　:(COLONCATEGORY)　 (WHITESPACE)　: (COLONCATEGORY)　什麼(Nep)　飯店(Nc)　的(DE)　詳細(VH)　事情(Na)　，(COMMACATEGORY)　幾月(Nd)　幾(Neu)　號(Nf)　幾點(Nd)　，(COMMACATEGORY)　都(D)　寫(VC)　得(DE)　一清二楚
# (VH)　:(COLONCATEGORY)　 : (FW)　有沒有(D)　為何(D)　大牙(VC)　十幾(Neu)　年(Nf)　前(Ng)　事(Na)　，(COMMACATEGORY)　能(D)　記(VK)　那麼(D)　清楚(VH)　?(QUESTIONCATEGORY)
#
# (WHITESPACE)　有的(Neqa)　南京(Nc)　大屠殺(VC)
#
# (WHITESPACE)　228
#
# (Nb)　不(D)　是(SHI)　當事人(Na)
#
# (WHITESPACE)　都(D)　還(D)　記得(VK)　一清二楚
#
#
# (Nd)　十(Neu)　年(Nf)　前(Ng)　的(DE)　事(Na)　 (WHITESPACE)　還是(Caa)　當事人(Na)
#
# (WHITESPACE)　還好(D)　吧
#
# --
# (VA)
# (46, 50, 'DATE', '十幾年前')
# (147, 151, 'DATE', '兩三年前')
# (177, 179, 'CARDINAL', '幾千')
# (228, 232, 'DATE', '十幾年前')
# (245, 250, 'EVENT', '南京大屠殺')
# (275, 278, 'DATE', '十年前')
#
# '作者ck3935 (鼻涕)看板Gossiping標題[問卦] 范瑋琪-如果的事  到底是甚麼事時間Tue Jun 27 15:28:34 2023
# 如果你已經不能控制 每天想我一次
#
# 如果你因為我而誠實~~
#
#
#
# 2012年范瑋琪跟張韶涵合唱的歌
#
# 雖然後來兩個人已經鬧翻了 但歌本身還是很好聽的
#
# 所以如果的事  到底是甚麼事
#
# 有沒有八卦
#
# --
# '
# 作者(Na)　ck(FW)　3935(Neu)　 (WHITESPACE)　((PARENTHESISCATEGORY)　鼻涕(Na)　)(PARENTHESISCATEGORY)　看板(Na)　Gossiping(FW)　標題(Na)　[(PARENTHESISCATEGORY)　問卦(Na)　] (FW)　范瑋琪(Nb)　-(DASHCATEGORY)　如果(Cbb)　的(DE)　事(Na)　  (WHITESPACE)　到底(D)　是(SHI)　甚麼(Nep)　事(Na)　時間(Na)　Tue Jun (FW)　27(Neu)　 (WHITESPACE)　15:28:34(Neu)　 (WHITESPACE)　2023
# (Neu)　如果(Cbb)　你(Nh)　已經(D)　不能(D)　控制(VC)　 (WHITESPACE)　每(Nes)　天(Nf)　想(VE)　我(Nh)　一(Neu)　次(Nf)
#
# (WHITESPACE)　如果(Cbb)　你(Nh)　因為(Cbb)　我(Nh)　而(Cbb)　誠實(VH)　~~
#
#
#
# (FW)　2012年(Nd)　范瑋琪(Nb)　跟(P)　張韶涵(Nb)　合唱(VC)　的(DE)　歌
#
# (Na)　雖然(Cbb)　後來(Nd)　兩(Neu)　個(Nf)　人(Na)　已經(D)　鬧翻(VH)　了(T)　 (WHITESPACE)　但(Cbb)　歌(Na)　本身(Nh)　還是(D)　很(Dfa)　好聽(VH)　的(DE)
#
# (WHITESPACE)　所以(Cbb)　如果(Cbb)　的(DE)　事(Na)　  (WHITESPACE)　到底(D)　是(SHI)　甚麼(Nep)　事(Na)
#
# (WHITESPACE)　有(V_2)　沒(D)　有(V_2)　八卦
#
# --
# (Na)
# (31, 34, 'PERSON', '范瑋琪')
# (107, 112, 'DATE', '2012年')
# (112, 115, 'PERSON', '范瑋琪')
# (116, 119, 'PERSON', '張韶涵')
# (129, 130, 'CARDINAL', '兩')
#
# '作者int1000 (小p)看板Gossiping標題Re: [新聞] 大牙32C激凸　陳建州：快APP給我看時間Tue Jun 27 15:28:01 2023
# ※ 引述《st797912 (般若波羅蜜)》之銘言：
# : 1.媒體來源:
# : ETT新聞
# : 2.記者署名:
# : 記者張瀞勻／台北報導
# : 3.完整新聞標題:
# : 【辣圖】大牙32C激凸　陳建州：快APP給我看！
# : 4.完整新聞內文:
# : 黑澀會美眉出身的大牙(周宜霈)曾擔任女子團體「黑Girl」團長，「黑Girl」解散後，加
# : 入傳奇星旗下。而以往都擔任班長角色的她，陽剛味超重，她笑說自己小時候就是擔任「
# : 抓耙仔」、「風紀股長」，這回突破尺度拍攝偷窺寫真集，甚至曝光32C激凸畫面，連老
# : 闆陳建州(黑人)都驚訝小女孩長大了，大牙笑說：「一拍完，黑人老大就叫我APP幾張來
# : 看看！」
# : 陳建州看了照片很驚訝，連好友張智成也看傻了眼直誇：「真的很不一樣！」大牙笑說：
# : 「為了寫真集，我留了這輩子以來最長的頭髮，以前都覺得留長頭髮很麻煩，這次經紀公
# : 司要我留長，還不准我染頭髮，不過宣傳完寫真集，我打算找時間去剪短了！」
# : 5.完整新聞連結 (或短網址)不可用YAHOO、LINE、MSN等轉載媒體：
# : https://star.ettoday.net/news/152575
# : 6.備註:
# : 看樣子黑人老大是真的很想看
# : 2012年沒看到，2013年看有沒有機會看一波
# : 是不是因為有人不愛那檔事啊？
#
#
# 2012年差點被噁男黑人性侵
#
# 2013年兩人又能談笑風生
#
# 這不就說明這兩人關係不尋常
#
# 會不會最後范范才是受害者
#
# --
# '
# 作者(Na)　int(FW)　1000(Neu)　 (WHITESPACE)　((PARENTHESISCATEGORY)　小(VH)　p(FW)　)(PARENTHESISCATEGORY)　看板(Na)　Gossiping(FW)　標題(Na)　Re: [(FW)　新聞(Na)　] (FW)　大牙(Na)　32(Neu)　C(FW)　激凸(Na)　　(WHITESPACE)　陳建州(Nb)　：(COLONCATEGORY)　快(VH)　APP(FW)　給(VD)　我(Nh)　看(VC)　時間(Na)　Tue Jun (FW)　27(Neu)　 (WHITESPACE)　15:28:01(Neu)　 (WHITESPACE)　2023
# (Neu)　※ (FW)　引述(VC)　《(PARENTHESISCATEGORY)　st(FW)　797912(Neu)　 (WHITESPACE)　((PARENTHESISCATEGORY)　般若波羅蜜(Nb)　)(PARENTHESISCATEGORY)　》(PARENTHESISCATEGORY)　之(DE)　銘言(Na)　：(COLONCATEGORY)
# (WHITESPACE)　: 1(Neu)　.(PERIODCATEGORY)　媒體(Na)　來源(Na)　:
# : ETT(FW)　新聞(Na)
# (WHITESPACE)　: 2(Neu)　.(PERIODCATEGORY)　記者(Na)　署名(VC)　:(COLONCATEGORY)
# (WHITESPACE)　:(COLONCATEGORY)　 (WHITESPACE)　記者(Na)　張瀞勻(Nb)　／(FW)　台北(Nc)　報導(VE)
# (WHITESPACE)　: 3(Neu)　.(PERIODCATEGORY)　完整(VH)　新聞(Na)　標題(Na)　:(COLONCATEGORY)
# (WHITESPACE)　:(COLONCATEGORY)　 (WHITESPACE)　【(PARENTHESISCATEGORY)　辣圖(Nb)　】(PARENTHESISCATEGORY)　大牙(Nb)　32(Neu)　C(FW)　激凸(Na)　　(WHITESPACE)　陳建州(Nb)　：(COLONCATEGORY)　快(VH)　APP(FW)　給(VD)　我(Nh)　看(VC)　！
# (FW)　: 4(FW)　.(PERIODCATEGORY)　完整(VH)　新聞(Na)　內文(Na)　:(COLONCATEGORY)
# (WHITESPACE)　:(COLONCATEGORY)　 (WHITESPACE)　黑澀(Na)　會(D)　美眉(Na)　出身(VJ)　的(DE)　大牙(Na)　((PARENTHESISCATEGORY)　周宜霈(Nb)　)(PARENTHESISCATEGORY)　曾(D)　擔任(VG)　女子(Na)　團體(Na)　「(PARENTHESISCATEGORY)　黑(VH)　Girl(FW)　」(PARENTHESISCATEGORY)　團長(Na)　，(COMMACATEGORY)　「(PARENTHESISCATEGORY)　黑(VH)　Girl(FW)　」(PARENTHESISCATEGORY)　解散(VHC)　後(Ng)　，(COMMACATEGORY)　加
# (WHITESPACE)　: 5(FW)　.(PERIODCATEGORY)　完整(VH)　新聞(Na)　連結(VC)　 (WHITESPACE)　((PARENTHESISCATEGORY)　或(Caa)　短(VH)　網址(Na)　)(PARENTHESISCATEGORY)　不可(D)　用(P)　YAHOO(FW)　、(PAUSECATEGORY)　LINE(FW)　、(PAUSECATEGORY)　MSN(FW)　等(Cab)　轉載(VC)　媒體(Na)　：
# : https://star.ettoday.net/news/152575
# (Neu)　:(COLONCATEGORY)　 6(FW)　.(PERIODCATEGORY)　備註(VE)　:(COLONCATEGORY)
# (WHITESPACE)　:(COLONCATEGORY)　 (WHITESPACE)　看樣子(D)　黑人(Na)　老大(Na)　是(SHI)　真的(D)　很(Dfa)　想(VE)　看(VC)
# : (Na)　2012年(Nd)　沒(D)　看到(VE)　，(COMMACATEGORY)　2013年(Nd)　看(VC)　有(V_2)　沒(D)　有(V_2)　機會(Na)　看(VC)　一(Neu)　波(Nf)
# (WHITESPACE)　:(COLONCATEGORY)　 (WHITESPACE)　是(SHI)　不(D)　是(SHI)　因為(Cbb)　有(V_2)　人(Na)　不(D)　愛(VL)　那(Nep)　檔(Nf)　事(Na)　啊(T)　？
#
#
# (FW)　2012年(Nd)　差點(D)　被(P)　噁(VH)　男(Na)　黑(VH)　人性(Na)　侵(VC)
#
# (WHITESPACE)　2013年(Nd)　兩(Neu)　人(Na)　又(D)　能(D)　談笑風生
#
# (VA)　這(Nep)　不(D)　就(D)　說明(VE)　這(Nep)　兩(Neu)　人(Na)　關係(Na)　不尋常(VH)
#
# (WHITESPACE)　會不會(D)　最後(Nd)　范范(Nb)　才(Da)　是(SHI)　受害(VH)　者(Na)
#
# --
# (FW)
# (44, 47, 'PERSON', '陳建州')
# (141, 144, 'PERSON', '張瀞勻')
# (145, 147, 'GPE', '台北')
# (176, 179, 'PERSON', '陳建州')
# (214, 217, 'PERSON', '周宜霈')
# (322, 324, 'CARDINAL', '32')
# (336, 339, 'PERSON', '陳建州')
# (386, 389, 'PERSON', '陳建州')
# (400, 403, 'PERSON', '張智成')
# (612, 617, 'DATE', '2012年')
# (621, 626, 'DATE', '2013年')
# (671, 676, 'DATE', '2013年')
# (692, 693, 'CARDINAL', '兩')
# (706, 708, 'PERSON', '范范')
#
# '作者t127147157 (Dark Knight)看板Gossiping標題Re: [問卦] 平心而論 大牙算是正妹嗎？時間Tue Jun 27 15:27:51 2023
# ※ 引述《norvasc (Norton)》之銘言：
# : 這是大牙以前到現在的照片
# : 算是黑肉底
# : https://i.imgur.com/uARXRYr.jpg
# : https://i.imgur.com/oi8d6Im.jpg
# : https://i.imgur.com/MIUBbYu.jpg
# : https://i.imgur.com/wQO3go6.jpg
# : 台灣男生好像都喜歡白一點的？
# : 平心而論 大牙算是正妹嗎？
#
# 想到這個也很好笑
#
# N年前 黑澀會還在時
#
# 某同學為了這個氣呼呼
#
# 某禿頭同學說大牙很正
#
# 問我覺得怎樣?
#
# 我說覺得大牙還好而已
#
# 他就暴氣了說:
#
# "乾 大牙免費讓你乾你要不要?"
#
# 現在這句話來問八卦肥宅好了
#
# 有沒有八卦?
#
# --
# '
# 作者(Na)　t127147157(Nb)　 (WHITESPACE)　((PARENTHESISCATEGORY)　Dark Knight(FW)　)(PARENTHESISCATEGORY)　看板(Na)　Gossiping(FW)　標題(Na)　Re: [(FW)　問(VE)　卦(Na)　] (PARENTHESISCATEGORY)　平心而論(VA)　 大牙(Na)　算是(VG)　正妹(Na)　嗎(T)　？(QUESTIONCATEGORY)　時間(Na)　Tue Jun (FW)　27(Neu)　 (WHITESPACE)　15:27:51(Nd)　 (WHITESPACE)　2023
# (Nd)　※ (FW)　引述(VC)　《(PARENTHESISCATEGORY)　norvasc (FW)　((PARENTHESISCATEGORY)　Norton(FW)　)(PARENTHESISCATEGORY)　》(PARENTHESISCATEGORY)　之(DE)　銘言(Na)　：(COLONCATEGORY)
# (WHITESPACE)　:(COLONCATEGORY)　 (WHITESPACE)　這(Nep)　是(SHI)　大牙(Na)　以前(Nd)　到(P)　現在(Nd)　的(DE)　照片
# (Na)　:(COLONCATEGORY)　 (WHITESPACE)　算是(VG)　黑肉底
# (Nb)　: https://i.imgur.com/uARXRYr.jpg
# : https://i.imgur.com/oi8d6Im.jpg
# : https://i.imgur.com/MIUBbYu.jpg
# : https://i.imgur.com/wQO3go6(Neu)　.jpg
# (FW)　: (PARENTHESISCATEGORY)　台灣(Nc)　男生(Na)　好像(D)　都(D)　喜歡(VK)　白(VH)　一點(Dfb)　的(DE)　？
# (FW)　:(COLONCATEGORY)　 (WHITESPACE)　平心而論(VA)　 (WHITESPACE)　大牙(Na)　算是(VG)　正妹(Na)　嗎(T)　？(QUESTIONCATEGORY)
#
# (WHITESPACE)　想到(VE)　這(Nep)　個(Nf)　也(D)　很(Dfa)　好笑(VH)
#
# N(FW)　年前(Nd)　 (WHITESPACE)　黑澀(Na)　會(D)　還(D)　在(P)　時
#
# (Nb)　某(Nes)　同學(Na)　為了(P)　這(Nep)　個(Nf)　氣呼呼
#
# (Na)　某(Nes)　禿頭(VH)　同學(Na)　說(VE)　大(VH)　牙(Na)　很(Dfa)　正
#
# (VH)　問(VE)　我(Nh)　覺得(VK)　怎樣(VH)　?(QUESTIONCATEGORY)
#
# (WHITESPACE)　我(Nh)　說(VE)　覺得(VK)　大牙(Na)　還好(VH)　而已(T)
#
# (WHITESPACE)　他(Nh)　就(D)　暴氣(VH)　了(Di)　說(VE)　:(COLONCATEGORY)
#
# "(FW)　乾(VH)　 (WHITESPACE)　大(VH)　牙(Na)　免費(VH)　讓(VL)　你(Nh)　乾(VH)　你(Nh)　要不要(D)　?(QUESTIONCATEGORY)　"
#
# (FW)　現在(Nd)　這(Nep)　句(Nf)　話(Na)　來(D)　問(VE)　八卦(Na)　肥宅(Na)　好了(T)
#
# (WHITESPACE)　有(V_2)　沒(D)　有(V_2)　八卦(Na)　?(QUESTIONCATEGORY)
#
# --
# (FW)
# (276, 278, 'NORP', '台灣')
#
# '作者leon131417 ()看板Gossiping標題Re: [問卦] 月底剩一千撐得到統一獅封王優惠嗎？時間Tue Jun 27 15:27:35 2023
# 沒事兒
#
# 先擔心
#
# 會不會封王吧
#
# 最近統一近況很糟糕
#
# 這週怕會翻車
#
# 變成別隊拿到
#
# 嗚嗚嗚嗚
#
# ※ 引述《Darvish903 (頭髮捲慘了)》之銘言：
# : 欸欸 4窩肥ㄦ喇
# : 本肥ㄦ的朋友喇
# : 端午節四天連假
# : 不小心錢花太兇
# : 現在戶頭剩一千
# : 還要撐到下個月
# : 十號才能領薪水
# : 聽說統一快封王
# : 最快這禮拜達成
# : 現在把錢省著用
# : 等統一封王優惠
# : 一次買齊補給品
# : 有沒有點搞頭啊
# : 呱呱
#
# -----
# Sent from JPTT on my iPhone
#
# --
# '
# 作者(Na)　leon(FW)　131417(Neu)　 (WHITESPACE)　((PARENTHESISCATEGORY)　)(PARENTHESISCATEGORY)　看板(Na)　Gossiping(FW)　標題(Na)　Re: [(FW)　問卦(Na)　] (FW)　月底(Nd)　剩(VJ)　一千(Neu)　撐(VC)　得到(VJ)　統一獅(Nb)　封王(VA)　優惠(VJ)　嗎(T)　？(QUESTIONCATEGORY)　時間(Na)　Tue Jun (FW)　27(Neu)　 (WHITESPACE)　15:27:35(Nd)　 (WHITESPACE)　2023
# (Nd)　沒(VJ)　事兒(Na)
#
# (WHITESPACE)　先(D)　擔心(VK)
#
# (WHITESPACE)　會不會(D)　封王吧
#
# (Na)　最近(Nd)　統一(VHC)　近況(Na)　很(Dfa)　糟糕(VH)
#
# (WHITESPACE)　這(Nep)　週(Nf)　怕(VK)　會(D)　翻車(VH)
#
# (WHITESPACE)　變成(VG)　別(Nes)　隊(Na)　拿到(VC)
#
# (WHITESPACE)　嗚嗚(D)　嗚嗚(D)
#
# (WHITESPACE)　※ (FW)　引述(VC)　《(PARENTHESISCATEGORY)　Darvish(FW)　903(Neu)　 (WHITESPACE)　((PARENTHESISCATEGORY)　頭髮(Na)　捲慘(VC)　了(T)　)(PARENTHESISCATEGORY)　》(PARENTHESISCATEGORY)　之(DE)　銘言(Na)　：(COLONCATEGORY)
# (WHITESPACE)　:(COLONCATEGORY)　 (WHITESPACE)　欸欸 4(I)　窩肥(Nb)　ㄦ喇
# (FW)　:(COLONCATEGORY)　 本(FW)　肥ㄦ(VH)　的(DE)　朋友(Na)　喇
# (VE)　:(COLONCATEGORY)　 (WHITESPACE)　端午節(Nd)　四(Neu)　天(Nf)　連(Cbb)　假
# (VA)　:(COLONCATEGORY)　 (WHITESPACE)　不(D)　小心(VK)　錢(Na)　花(VC)　太(Dfa)　兇
# (VH)　: (COLONCATEGORY)　現在(Nd)　戶頭(Na)　剩(VJ)　一千(Neu)
# (WHITESPACE)　: (FW)　還要(Dfa)　撐到(VC)　下(Nes)　個(Nf)　月
# (Na)　:(COLONCATEGORY)　 (WHITESPACE)　十(Neu)　號(Nf)　才(Da)　能(D)　領(VC)　薪水
# (Na)　:(COLONCATEGORY)　 (WHITESPACE)　聽說(VE)　統一(VHC)　快(D)　封(VG)　王
# (Na)　:(COLONCATEGORY)　 (WHITESPACE)　最(Dfa)　快(VH)　這(Nep)　禮拜(Na)　達成(VC)
# (WHITESPACE)　:(COLONCATEGORY)　 (WHITESPACE)　現在(Nd)　把(P)　錢(Na)　省(VJ)　著(Di)　用
# (Na)　:(COLONCATEGORY)　 (WHITESPACE)　等(Cab)　統一(VHC)　封(VG)　王優惠
# (Nb)　:(COLONCATEGORY)　 (WHITESPACE)　一(Neu)　次(Nf)　買齊(VC)　補給(VD)　品
# (Na)　:(COLONCATEGORY)　 (WHITESPACE)　有(V_2)　沒(D)　有(V_2)　點(Nf)　搞頭(Na)　啊
# (T)　:(COLONCATEGORY)　 呱呱
#
# -----
# Sent from JPTT on my iPhone
#
# --
# (FW)
# (2, 6, 'PERSON', 'leon')
# (37, 39, 'DATE', '月底')
# (40, 42, 'CARDINAL', '一千')
# (45, 48, 'ORG', '統一獅')
# (224, 226, 'DATE', '十號')
# (274, 275, 'CARDINAL', '一')
#
# '作者teeo (teeo)看板Gossiping標題[問卦] 台灣還剩什麼圈？時間Tue Jun 27 15:26:07 2023
# 政治圈之後
# 演藝圈
# 看樣子要大爆炸了
# 大家應該都在等上車吧！
#
# 這樣搞一輪
# 台灣還剩下什麼圈圈是乾淨的呢？
# 塔綠圈？
# 哥布林圈？
# 只要沒退出是不是就贏了！
#
# --
# '
# 作者(Na)　teeo (FW)　((PARENTHESISCATEGORY)　teeo(FW)　)(PARENTHESISCATEGORY)　看板(Na)　Gossiping(FW)　標題(Na)　[(PARENTHESISCATEGORY)　問卦(Na)　] (FW)　台灣(Nc)　還(D)　剩(VJ)　什麼(Nep)　圈(Na)　？(QUESTIONCATEGORY)　時間(Na)　Tue Jun (FW)　27(Neu)　 (WHITESPACE)　15:26:07(Nd)　 (WHITESPACE)　2023
# (Nd)　政治圈(Nc)　之後(Ng)
# (WHITESPACE)　演藝(A)　圈
# (Na)　看樣子(D)　要(D)　大(VH)　爆炸(VH)　了(Di)
# (WHITESPACE)　大家(Nh)　應該(D)　都(D)　在(D)　等(VC)　上車(VA)　吧(T)　！(EXCLAMATIONCATEGORY)
#
# (WHITESPACE)　這樣(VH)　搞(VC)　一(Neu)　輪(Nf)
# (WHITESPACE)　台灣(Nc)　還(D)　剩下(VJ)　什麼(Nep)　圈圈(Na)　是(SHI)　乾淨(VH)　的(T)　呢(T)　？(QUESTIONCATEGORY)
# 塔(Na)　綠圈(Na)　？(QUESTIONCATEGORY)
# 哥(Na)　布林圈(Nc)　？(QUESTIONCATEGORY)
# (WHITESPACE)　只要(Cbb)　沒(D)　退出(VCL)　是(SHI)　不(D)　是(SHI)　就(D)　贏(VD)　了(Di)　！(EXCLAMATIONCATEGORY)
#
# --
# (FW)
# (31, 33, 'GPE', '台灣')
# (104, 106, 'GPE', '台灣')
#
# '作者Kimmy (Kimi)看板Gossiping標題Re: [問卦] 為何大牙十幾年前事，能記那麼清楚?時間Tue Jun 27 15:25:27 2023
# ※ 引述《kikiki37 (441)》之銘言：
# : 阿諾內，我大概兩三年前的事就記不清楚了
# : 但看到大牙文章，隨便就寫了幾千字，內容鉅細靡遺
# : 什麼飯店的詳細事情，幾月幾號幾點，都寫得一清二楚
# : 有沒有為何大牙十幾年前事，能記那麼清楚?
#
# 為毛殺人犯可以被原諒
# 這種性騷還未遂
# 要抄家滅族?
# 不就說親個嘴而已
# 真有這麼可怕？
# 當所有人都很純情喔?
# 老實說
# 就算性侵成功
# 罰罰二三月薪水就差不多了
# 再無線上綱要求幾百萬
# 就不支持了
# metoo該適可而止了
# 不然男女對立
# 只會愈來愈嚴重啦
# 偶要來拯救目前女權歪風
# 殺人、酒駕、飆車、棒球隊
# 這些絕對比較嚴重
# 讓這些社死可以拯救更多人
# 瓜!!
#
# --
# '
# 作者(Na)　Kimmy (FW)　((PARENTHESISCATEGORY)　Kimi(FW)　)(PARENTHESISCATEGORY)　看板(Na)　Gossiping(FW)　標題(Na)　Re: [(FW)　問卦(Na)　] (FW)　為何(D)　大牙(VC)　十幾(Neu)　年(Nf)　前(Ng)　事(Na)　，(COMMACATEGORY)　能(D)　記(VK)　那麼(D)　清楚(VH)　?(QUESTIONCATEGORY)　時間(Na)　Tue Jun (FW)　27(Neu)　 (WHITESPACE)　15:25:27(Nd)　 (WHITESPACE)　2023
# (Nd)　※ (FW)　引述(VC)　《(PARENTHESISCATEGORY)　kikiki(FW)　37(Neu)　 (WHITESPACE)　(441)(Nd)　》(PARENTHESISCATEGORY)　之(DE)　銘言(Na)　：(COLONCATEGORY)
# (WHITESPACE)　:(COLONCATEGORY)　 (WHITESPACE)　阿諾內(Nb)　，(COMMACATEGORY)　我(Nh)　大概(D)　兩三(Neu)　年(Nf)　前(Ng)　的(DE)　事(Na)　就(D)　記(VK)　不(D)　清楚(VH)　了(Di)
# (WHITESPACE)　:(COLONCATEGORY)　 (WHITESPACE)　但(Cbb)　看到(VE)　大牙(Na)　文章(Na)　，(COMMACATEGORY)　隨便(VH)　就(D)　寫(VC)　了(Di)　幾千(Neu)　字(Na)　，(COMMACATEGORY)　內容(Na)　鉅細靡遺
# (VH)　:(COLONCATEGORY)　 (WHITESPACE)　什麼(Nep)　飯店(Nc)　的(DE)　詳細(VH)　事情(Na)　，(COMMACATEGORY)　幾月(Nd)　幾(Neu)　號(Nf)　幾點(Nd)　，(COMMACATEGORY)　都(D)　寫(VC)　得(DE)　一清二楚
# (VH)　:(COLONCATEGORY)　 (WHITESPACE)　有沒有(D)　為何(D)　大牙(VC)　十幾(Neu)　年(Nf)　前(Ng)　事(Na)　，(COMMACATEGORY)　能(D)　記(VK)　那麼(D)　清楚(VH)　?(QUESTIONCATEGORY)
#
# (WHITESPACE)　為(P)　毛殺(Nb)　人犯(Na)　可以(D)　被(P)　原諒
# (Nb)　這(Nep)　種(Nf)　性騷(Na)　還(D)　未遂
# (D)　要(D)　抄家(VA)　滅族(VB)　?(QUESTIONCATEGORY)
# (WHITESPACE)　不(D)　就(D)　說(VE)　親(VJ)　個(Nf)　嘴(Na)　而已(T)
# (WHITESPACE)　真(D)　有(V_2)　這麼(Dfa)　可怕(VH)　？
# (FW)　當(VG)　所有人(Na)　都(D)　很(Dfa)　純情(VH)　喔(T)　?(QUESTIONCATEGORY)
# (WHITESPACE)　老實(VH)　說
# (VA)　就算(Cbb)　性侵成功
# (VH)　罰罰(VC)　二三月(Nd)　薪水(Na)　就(D)　差不多(VH)　了(Di)
# (WHITESPACE)　再(D)　無線(A)　上綱(VH)　要求(VF)　幾百萬(Neu)
# (WHITESPACE)　就(D)　不(D)　支持(VC)　了(Di)
# metoo(FW)　該(D)　適可而止(VH)　了(Di)
# (WHITESPACE)　不然(Cbb)　男女(Na)　對立
# (VA)　只(Da)　會(D)　愈來愈(Dfa)　嚴重(VH)　啦(T)
# 偶(Na)　要(D)　來(D)　拯救(VC)　目前(Nd)　女權(Na)　歪風
# (Na)　殺人(VA)　、(PAUSECATEGORY)　酒駕(Na)　、(PAUSECATEGORY)　飆車(VA)　、(PAUSECATEGORY)　棒球隊
# (Na)　這些(Neqa)　絕對(D)　比較(Dfa)　嚴重(VH)
# (WHITESPACE)　讓(VL)　這些(Neqa)　社死(Na)　可以(D)　拯救(VC)　更多(Neqa)　人(Na)
# 瓜(Na)　!(EXCLAMATIONCATEGORY)　!(EXCLAMATIONCATEGORY)
#
# --
# (FW)
# (2, 8, 'PERSON', 'Kimmy ')
# (40, 44, 'DATE', '十幾年前')
# (114, 115, 'DATE', '兩')
# (142, 144, 'CARDINAL', '幾千')
# (189, 193, 'DATE', '十幾年前')
#
# '作者qwqwaas (MADE)看板Gossiping標題[問卦] 黑人怎麼敢去惹大牙阿?時間Tue Jun 27 15:25:11 2023
# 雖然沒在看黑澀會
#
# 但印象中大牙看起來就很兇又敢講話又偏執
#
# 感覺就是不爽會直接出來跟你對槓的
#
# 以當時黑人的立場怎麼敢去玩她阿
#
# 風險太高了吧
#
# 如果是真的話那讓我滿訝異的
#
# 是要多蠢才會做這種事
#
# 以他當時的身份撇清都來不及了還敢有非份之想
#
# --
# '
# 作者(Na)　qwqwaas (FW)　((PARENTHESISCATEGORY)　MADE(FW)　)(PARENTHESISCATEGORY)　看板(Na)　Gossiping(FW)　標題(Na)　[(PARENTHESISCATEGORY)　問(VE)　卦(Na)　] (FW)　黑人(Na)　怎麼(D)　敢(VL)　去(D)　惹(VC)　大牙阿(Na)　?(QUESTIONCATEGORY)　時間(Na)　Tue Jun (FW)　27(Neu)　 (WHITESPACE)　15:25:11(Nd)　 (WHITESPACE)　2023
# (Nd)　雖然(Cbb)　沒(D)　在(P)　看(VC)　黑澀(Na)　會(D)
#
# (WHITESPACE)　但(Cbb)　印象(Na)　中(Ng)　大牙(Na)　看起來(D)　就(D)　很(Dfa)　兇(VH)　又(D)　敢(VL)　講話(VA)　又(D)　偏執(VH)
#
# (WHITESPACE)　感覺(Na)　就(D)　是(SHI)　不(D)　爽(VH)　會(D)　直接(VH)　出來(VA)　跟(P)　你(Nh)　對槓(VA)　的(DE)
#
# (WHITESPACE)　以(P)　當時(Nd)　黑人(Na)　的(DE)　立場(Na)　怎麼(D)　敢(VL)　去(D)　玩(VC)　她(Nh)　阿
#
# (Nb)　風險(Na)　太(Dfa)　高(VH)　了(T)　吧(T)
#
# (WHITESPACE)　如果(Cbb)　是(SHI)　真(VH)　的話(Cba)　那(Nep)　讓(VL)　我(Nh)　滿(Dfa)　訝異(VK)　的(DE)
#
# (WHITESPACE)　是(SHI)　要(D)　多(Dfa)　蠢(VH)　才(Da)　會(D)　做(VC)　這(Nep)　種(Nf)　事(Na)
#
# (WHITESPACE)　以(P)　他(Nh)　當時(Nd)　的(DE)　身份(Na)　撇清(VC)　都(D)　來不及(VH)　了(Di)　還(D)　敢(VL)　有(V_2)　非份(A)　之(DE)　想(Nv)
#
# --
# (FW)
#
# '作者wujet09100 (噁爛臭酸肥宅)看板Gossiping標題[新聞] 羅一鈞點名「三縣市」登革熱最高風險！ /時間Tue Jun 27 15:24:50 2023
#
# 羅一鈞點名「三縣市」登革熱最高風險！ 台南兩區7/1起實施快篩即確診
#
# https://cnews.com.tw/003230627a08/
#
# 2023-06-27
# 陳 鈞凱
# 台南
# /
# 本土登革熱
# /
# 高雄
# 羅一鈞點名「三縣市」登革熱最高風險！ 台南兩區7/1起實施快篩即確診
# CNEWS匯流新聞網記者陳鈞凱／台北報導
# 南台灣本土登革熱正往上燒，疾管署今（27）日公布，國內上週新增55例登革熱本土病例，且繼台南之後，高雄也淪陷、出現當地今年首例個案。疾管署副署長羅一鈞也直接點名「南高屏」三縣市已經列為「最高風險」地區，嚴陣以待，而疾管署也宣布針對目前重災區的台南市仁德區和東區，為減少確診的時間差，這兩區從7月1日起全面實施「快篩陽性即確診」新制。
# 疾管署下午公布國內上週新增55例登革熱本土病例，個案居住地為台南市54例及高雄市1例，分別於台南市仁德區38例、東區11例、永康區、北區、南區、安南區、善化區及高雄市茄萣區各1例。新增病例多與目前疫情群聚區的台南市仁德區與東區交界具關聯性。
# 值得注意的是，國內今年截至6月26日累計72例本土病例，其中台南市71例，以仁德區51例和東區14例為主，病毒型別均為第一型，病例數已達2017年同期以來最高。
# 羅一鈞表示，這一波本土登革熱目前難以預估高峰將落在何時，但台南、高雄、屏東這三縣市列為最高風險，因為全是埃及斑蚊棲息地，加上區域中的人口流動高，是風險最高的區域；不過，其他縣市也有白線斑蚊，風險也可能隨著人潮交流而增加，更何況今年境外移入風險也增高，儘管防疫措施著重南台灣，但全台灣其實都不能掉以輕心。
# 羅一鈞分析，目前本土登革熱個案4成為60歲以上以上長者，一旦感染登革熱可能加重本身的慢性病或增加出血的風險，而埃及斑蚊的特性是喜歡在家戶陰涼處棲息，滿多長者都是在家裡頭或是前往常活動的公共場所，如宮廟、公有市場等處遭叮咬，因此，不出門也要做好防蚊措施，並避免在清晨、黃昏病媒蚊出沒高峰時活動，清除家中積水容器。
# 羅一鈞提醒，慢性病患者、孕婦、嬰兒、年長者等高危險群，應注意自身有無登革熱警示徵象，包括：腹部疼痛及壓痛、持續性嘔吐、黏膜出血、嗜睡及躁動不安等4大症狀，以降低登革熱重症的發生。
# (WHITESPACE)　羅一鈞(Nb)　提醒(VE)　，(COMMACATEGORY)　慢性病(Na)　患者(Na)　、(PAUSECATEGORY)　孕婦(Na)　、(PAUSECATEGORY)　嬰兒(Na)　、(PAUSECATEGORY)　年長(VH)　者(Na)　等(Cab)　高(VH)　危險群(Na)　，(COMMACATEGORY)　應(D)　注意(VK)　自身(Nh)　有無(VJ)　登革熱(Na)　警示(VC)　徵象(Na)　，(COMMACATEGORY)　包括(VK)　：(COLONCATEGORY)　腹部(Nc)　疼痛(Na)　及(Caa)　壓痛(VH)　、(PAUSECATEGORY)　持續性(Na)　嘔吐(VA)　、(PAUSECATEGORY)　黏膜(Na)　出血(VH)　、(PAUSECATEGORY)　嗜(VL)　睡(VA)　及(Caa)　躁動(VH)　不安(VH)　等(Cab)　4(Neu)　大(VH)　症狀(Na)　，(COMMACATEGORY)　以(Cbb)　降低(VHC)　登革熱(Na)　重症(Na)　的(DE)　發生(VJ)　。
# (Na)　照片(Na)　來源(Na)　：(COLONCATEGORY)　CNEWS(FW)　資料照(Na)　／(FW)　記者(Na)　陳鈞凱(Nb)　攝
#
#
# (VA)　四(Neu)　個(Nf)　不(D)　同意(VK)　 (WHITESPACE)　登革熱(Na)　下去(Di)
#
# (WHITESPACE)　不(D)　同意(VK)　容器(Na)　積水(VH)
#
# (WHITESPACE)　不(D)　同意(VK)　不(D)　噴(VC)　防(VC)　蚊液(Na)
#
# (WHITESPACE)　不(D)　同意(VK)　紗窗(Na)　不關(VJ)
#
# (WHITESPACE)　不(D)　同意(VK)　短袖(Na)　短褲(Na)
#
# 蛤
#
# (Na)　快篩(VC)　楊姓(Nb)　等同(VG)　確診(VH)　知道(VK)　不(D)
#
# --
# (VH)
# (39, 42, 'PERSON', '羅一鈞')
# (45, 46, 'CARDINAL', '三')
# (93, 94, 'CARDINAL', '三')
# (106, 108, 'GPE', '台南')
# (110, 111, 'CARDINAL', '7')
# (112, 113, 'CARDINAL', '1')
# (210, 212, 'GPE', '台南')
# (214, 215, 'CARDINAL', '7')
# (216, 217, 'CARDINAL', '1')
# (238, 241, 'PERSON', '陳鈞凱')
# (242, 244, 'GPE', '台北')
# (247, 250, 'GPE', '南台灣')
# (260, 263, 'ORG', '疾管署')
# (265, 269, 'DATE', '27）日')
# (274, 276, 'DATE', '上週')
# (278, 280, 'CARDINAL', '55')
# (291, 293, 'GPE', '台南')
# (296, 298, 'GPE', '高雄')
# (306, 308, 'DATE', '今年')
# (313, 316, 'ORG', '疾管署')
# (319, 322, 'PERSON', '羅一鈞')
# (328, 331, 'GPE', '南高屏')
# (332, 333, 'CARDINAL', '三')
# (354, 357, 'ORG', '疾管署')
# (368, 374, 'GPE', '台南市仁德區')
# (389, 390, 'CARDINAL', '兩')
# (392, 396, 'DATE', '7月1日')
# (417, 419, 'TIME', '下午')
# (423, 425, 'DATE', '上週')
# (427, 429, 'CARDINAL', '55')
# (444, 447, 'GPE', '台南市')
# (447, 449, 'CARDINAL', '54')
# (451, 454, 'GPE', '高雄市')
# (454, 455, 'CARDINAL', '1')
# (460, 466, 'GPE', '台南市仁德區')
# (466, 468, 'CARDINAL', '38')
# (472, 474, 'CARDINAL', '11')
# (476, 479, 'GPE', '永康區')
# (486, 489, 'GPE', '安南區')
# (490, 493, 'GPE', '善化區')
# (494, 500, 'GPE', '高雄市茄萣區')
# (501, 502, 'CARDINAL', '1')
# (518, 524, 'GPE', '台南市仁德區')
# (544, 553, 'DATE', '今年截至6月26日')
# (555, 557, 'CARDINAL', '72')
# (565, 568, 'GPE', '台南市')
# (568, 570, 'CARDINAL', '71')
# (573, 576, 'GPE', '仁德區')
# (576, 578, 'CARDINAL', '51')
# (582, 584, 'CARDINAL', '14')
# (594, 596, 'ORDINAL', '第一')
# (603, 608, 'DATE', '2017年')
# (645, 647, 'GPE', '台南')
# (648, 650, 'GPE', '高雄')
# (651, 653, 'GPE', '屏東')
# (654, 655, 'CARDINAL', '三')
# (729, 731, 'DATE', '今年')
# (749, 752, 'GPE', '南台灣')
# (755, 757, 'GPE', '台灣')
# (783, 785, 'PERCENT', '4成')
# (786, 793, 'DATE', '60歲以上以上')
# (898, 900, 'TIME', '清晨')
# (996, 997, 'CARDINAL', '4')
#
# '作者ianlin1216 (伊恩可可)看板Gossiping標題[問卦] 結婚不能做愛到爽那結婚幹嘛時間Tue Jun 27 15:24:44 2023
# 餓死抬頭
# 不要說什麼結婚不只有性三小毒雞湯
# 我就不信世界上有智障願意付出幾百萬
# 上千萬買車買房
# 就為了娶一個不能幹的花瓶擺在家裡供著
# 婚後還要多分攤家務上繳薪水
# 性冷感的台女麻煩婚前說清楚好嗎
# 不要婚後才在那邊奧梨子裝蘋果
# 禍害台男
#
#
#
# 乾五八卦
#
# --
# '
# 作者(Na)　ianlin(FW)　1216(Neu)　 (WHITESPACE)　((PARENTHESISCATEGORY)　伊恩(Nb)　可可(Na)　)(PARENTHESISCATEGORY)　看板(Na)　Gossiping(FW)　標題(Na)　[(PARENTHESISCATEGORY)　問卦(Na)　] (FW)　結婚(VA)　不能(D)　做愛(VA)　到(P)　爽(VH)　那(Nep)　結婚(VA)　幹嘛(VA)　時間(Na)　Tue Jun (FW)　27(Neu)　 (WHITESPACE)　15:24:44(Neu)　 (WHITESPACE)　2023
# (Neu)　餓死(VHC)　抬頭
# (VA)　不要(D)　說(VE)　什麼(Nep)　結婚(VA)　不只(Da)　有(V_2)　性(Na)　三(Neu)　小(VH)　毒雞(Na)　湯
# (Nb)　我(Nh)　就(D)　不(D)　信(VK)　世界(Nc)　上(Ncd)　有(V_2)　智障(VH)　願意(VK)　付出(VC)　幾百萬(Neu)
# (WHITESPACE)　上千萬(Neu)　買(VC)　車(Na)　買(VC)　房
# (Na)　就(D)　為了(P)　娶(VC)　一(Neu)　個(Nf)　不(D)　能幹(VH)　的(DE)　花瓶(Na)　擺在(VCL)　家(Nc)　裡(Ncd)　供(VF)　著(Di)
# (WHITESPACE)　婚後(Nd)　還要(Dfa)　多(D)　分攤(VC)　家務(Na)　上(Ncd)　繳(VD)　薪水
# 性(Na)　冷感(VH)　的(DE)　台女(Na)　麻煩(VHC)　婚前(Nd)　說清楚(VC)　好(VH)　嗎(T)
# (WHITESPACE)　不要(D)　婚後(Nd)　才(Da)　在(P)　那邊(Ncd)　奧梨子(Na)　裝(VC)　蘋果
# (Na)　禍害(VC)　台男(Na)
#
#
#
# (WHITESPACE)　乾(VH)　五八卦
#
# --
# (Na)
# (2, 8, 'PERSON', 'ianlin')
# (93, 94, 'CARDINAL', '三')
# (113, 116, 'CARDINAL', '幾百萬')
# (117, 120, 'CARDINAL', '上千萬')
# (129, 130, 'CARDINAL', '一')
#
# '作者PPAPwww (pan)看板Gossiping標題[問卦] 台灣是不是跟辛巴威沒差多少？時間Tue Jun 27 15:24:24 2023
#
# 辛巴威貨幣變廢紙
#
# 但問題是台灣也發生過
# https://i.imgur.com/IR8KH0U.jpg
# 70年前發生過   你阿公就體驗過貨幣變廢紙
# 說久也不久
# 台灣歷史貨幣事件   40000元換1元
# 現在的1000元新台幣*4萬倍=40000000
# 好多0
#
# 才換新貨幣沒多久
# 貨幣額又越發越大了
# 是不是可以開始準備發行5000元新台幣了？
#
# --
# '
# 作者(Na)　PPAPwww (FW)　((PARENTHESISCATEGORY)　pan(FW)　)(PARENTHESISCATEGORY)　看板(Na)　Gossiping(FW)　標題(Na)　[(PARENTHESISCATEGORY)　問卦(Na)　] (FW)　台灣(Nc)　是(SHI)　不(D)　是(SHI)　跟(P)　辛巴威(Nc)　沒(D)　差(VH)　多少(Neqa)　？(QUESTIONCATEGORY)　時間(Na)　Tue Jun (FW)　27(Neu)　 (WHITESPACE)　15:24:24(Neu)　 (WHITESPACE)　2023
#
# (Nd)　辛巴威(Nc)　貨幣(Na)　變(VG)　廢紙(Na)
#
# (WHITESPACE)　但(Cbb)　問題(Na)　是(SHI)　台灣(Nc)　也(D)　發生(VJ)　過(Di)
# ...
# (WHITESPACE)　:(COLONCATEGORY)　 (WHITESPACE)　如果(Cbb)　當時(Nd)　可以(D)　勇敢(VH)　一點(Dfb)　公佈(VE)　他(Nh)　的(DE)　惡行(Na)　，(COMMACATEGORY)　或許(D)　就(D)　不用(D)　揹(VC)　著(Di)　忘恩負義(VH)　的(DE)　臭名(Na)　離開(VC)　經紀(A)　公司(Nc)　。(PERIODCATEGORY)　」(PARENTHESISCATEGORY)
# (WHITESPACE)　:(COLONCATEGORY)　 (WHITESPACE)　對(P)　此(Nep)　，(COMMACATEGORY)　陳建州(Nb)　透過(P)　律師(Na)　發出(VC)　聲明(Na)　回應(VC)　否認(VE)　指控(Na)　外(Ng)　，(COMMACATEGORY)　老婆(Na)　范瑋琪(Nb)　也(D)　透過(P)　經紀人(Na)　共同(A)　發出(VC)　同樣(VH)
# (WHITESPACE)　:(COLONCATEGORY)　 (WHITESPACE)　的(DE)　律師(Na)　聲明(VE)　，(COMMACATEGORY)　此(Nep)　舉(Na)　也(D)　等同(VG)　用以(D)　行動力(Na)　挺(VC)　老公(Na)　。
# (VA)　:(COLONCATEGORY)
# (WHITESPACE)　:(COLONCATEGORY)　 (WHITESPACE)　陳建州(Nb)　和(Caa)　范瑋琪(Nb)　共同(A)　發出(VC)　律師(Na)　聲明(Na)　表示(VE)　：(COLONCATEGORY)　「(PARENTHESISCATEGORY)　2012年(Nd)　7月(Nd)　香港(Nc)　錄製(VC)　節目(Na)　行程(Na)　，(COMMACATEGORY)　當事人(Na)　均(D)　為(VG)　團
# (Na)　:(COLONCATEGORY)　 體(FW)　行動(Na)　，(COMMACATEGORY)　絕無(VJ)　周(Nb)　 宜霈(Nb)　女士(Na)　指稱(VE)　私人(Nh)　獨處(VA)　之(DE)　事實(Na)　，(COMMACATEGORY)　周宜霈(Nb)　女士(Na)　之(DE)　指控(Na)　毫無(VJ)　根據(Na)　 (WHITESPACE)　、(PAUSECATEGORY)　全(Neqa)　屬(VG)　虛偽
# (Na)　:(COLONCATEGORY)　 (WHITESPACE)　不實(VH)　 (WHITESPACE)　。(PERIODCATEGORY)　當事人(Na)　行事(VA)　坦蕩(VH)　 (WHITESPACE)　，(COMMACATEGORY)　如(Cbb)　有(V_2)　行為(Na)　缺失(Na)　絕 (D)　對(P)　願意(VK)　積極(VH)　面對(VC)　 (WHITESPACE)　，(COMMACATEGORY)　但(Cbb)　若(Cbb)　有(V_2)　不實(VH)　指控(Na)　 (WHITESPACE)　，(COMMACATEGORY)　 (WHITESPACE)　無端
# (Na)　:(COLONCATEGORY)　 (WHITESPACE)　耗費(VC)　社會(Na)　大眾(Nh)　視聽(A)　 (WHITESPACE)　及(Caa)　媒體(Na)　資源(Na)　 (WHITESPACE)　，(COMMACATEGORY)　實(D)　為(VG)　不妥(VH)　 (WHITESPACE)　。(PERIODCATEGORY)　 (WHITESPACE)　本(Nes)　律師(Na)　將(D)　依(P)　當事人(Na)　委託(VF)　 (WHITESPACE)　，(COMMACATEGORY)　依法(D)　追究(VE)　相關(VH)
# (WHITESPACE)　覺得(VK)　現在(Nd)　范建(Nb)　夫妻(Na)　要(D)　反擊(VC)　很(Dfa)　容易(VH)
# (WHITESPACE)　只要(Cbb)　范范(Nb)　拿出(VC)　夫妻(Na)　間(Ng)　的(DE)　做愛(VA)　紀錄(Na)　就(D)　可以(D)　破(VHC)　大牙(Na)　說(VE)　的(DE)　話
# (Na)　或是(Caa)　當場(D)　表演(VC)　確認(VE)　是(SHI)　喜歡(VK)　的(DE)
# (WHITESPACE)　期待(VK)　可以(D)　拿出(VC)　實際(VH)　的(DE)　證據(Na)　去(D)　打(VC)　臉(Na)　大牙
#
# --
# Sent from my Google Pixel 7 Pro
#
# (Na)　○ PiTT // PHJCI
#
# --
# (FW)
# (2, 13, 'PERSON', 'amilkamilk ')
# (44, 47, 'PERSON', '范瑋琪')
# (51, 54, 'PERSON', '陳建州')
# (132, 135, 'PERSON', '范瑋琪')
# (139, 142, 'PERSON', '陳建州')
# (194, 197, 'PERSON', '范瑋琪')
# (201, 204, 'PERSON', '陳建州')
# (229, 232, 'PERSON', '翁子涵')
# (233, 235, 'GPE', '台北')
# (264, 269, 'ORG', '我愛黑澀會')
# (276, 279, 'DATE', '27日')
# (287, 290, 'PERSON', '陳建州')
# (290, 294, 'DATE', '11年前')
# (295, 297, 'GPE', '香港')
# (337, 340, 'PERSON', '陳建州')
# (361, 363, 'PERSON', '范范')
# (434, 437, 'PERSON', '陳建州')
# (455, 458, 'PERSON', '范瑋琪')
# (500, 503, 'PERSON', '陳建州')
# (504, 507, 'PERSON', '范瑋琪')
# (519, 526, 'DATE', '2012年7月')
# (526, 528, 'GPE', '香港')
# (552, 554, 'PERSON', '宜霈')
# (566, 569, 'PERSON', '周宜霈')
# (678, 680, 'PERSON', '范建')
# (691, 693, 'PERSON', '范范')
#
# '作者w510048 (黨的恩情比山高)看板Gossiping標題[問卦] 國中女生沒性慾為何會買按摩棒?時間Tue Jun 27 14:51:31 2023
# 大家都知道國中女生一般是沒什麼性慾。
# 可是居然有姐姐發現自己未成年的妹妹會買按摩棒：
# https://www.dcard.tw/f/mood/p/242656958
#
# 我想請問大家，
# 國中女生沒性慾為何會買按摩棒?
# 是不是很多男生會買女生低卡帳號來幻想呢?
# 為何低卡會有很多這種幻想文呢?
#
# 有沒有八卦呢?
#
# --
# '
# 作者(Na)　w(FW)　510048(Neu)　 (WHITESPACE)　((PARENTHESISCATEGORY)　黨(Na)　的(DE)　恩情(Na)　比(P)　山(Na)　高(VH)　)(PARENTHESISCATEGORY)　看板(Na)　Gossiping(FW)　標題(Na)　[(PARENTHESISCATEGORY)　問(VE)　卦(Na)　] (FW)　國中(Nc)　女生(Na)　沒(VJ)　性慾(Na)　為何(D)　會(D)　買(VC)　按摩棒(Na)　?(QUESTIONCATEGORY)　時間(Na)　Tue Jun (FW)　27(Neu)　 (WHITESPACE)　14:51:31(Nd)　 (WHITESPACE)　2023
# (Nd)　大家(Nh)　都(D)　知道(VK)　國中(Nc)　女生(Na)　一般(D)　是(SHI)　沒(VJ)　什麼(Nep)　性慾(Na)　。(PERIODCATEGORY)
# (WHITESPACE)　可是(D)　居然(D)　有(V_2)　姐姐(Na)　發現(VE)　自己(Nh)　未(D)　成年(VH)　的(DE)　妹妹(Na)　會(D)　買(VC)　按摩棒(Na)　：
# https://www(FW)　.dcard(Nb)　.tw/f/mood/p/242656958
#
# (Nb)　我(Nh)　想(VE)　請問(VE)　大家(Nh)　，(COMMACATEGORY)
# (WHITESPACE)　國中(Nc)　女生(Na)　沒(VJ)　性慾(Na)　為何(D)　會(D)　買(VC)　按摩棒(Na)　?(QUESTIONCATEGORY)
# (WHITESPACE)　是(SHI)　不(D)　是(SHI)　很多(Neqa)　男生(Na)　會(D)　買(VC)　女生(Na)　低卡(A)　帳號(Na)　來(D)　幻想(VE)　呢(T)　?(QUESTIONCATEGORY)
# (WHITESPACE)　為何(D)　低卡(Na)　會(D)　有(V_2)　很多(Neqa)　這(Nep)　種(Nf)　幻想文(Na)　呢(T)　?(QUESTIONCATEGORY)
#
# (WHITESPACE)　有(V_2)　沒(D)　有(V_2)　八卦(Na)　呢(T)　?(QUESTIONCATEGORY)
#
# --
# (FW)
# (2, 9, 'PERSON', 'w510048')
#
# '作者bingogobin (  )看板Gossiping標題[問卦] 還在關心餵藥案的是哪種人？時間Tue Jun 27 14:50:14 2023
# 剛剛滑臉書看到有些人說厭倦me too了
#
# 真正要關心的是新北餵藥案 沒有烏龍這種事
#
# 不是都被證實是假消息了嗎？
#
# 有沒有這些人的掛？
# ----
# Sent from BePTT on my iPhone 14 Pro Max
#
# --
# '
# 作者(Na)　bingogobin (FW)　((PARENTHESISCATEGORY)　  (WHITESPACE)　)(PARENTHESISCATEGORY)　看板(Na)　Gossiping(FW)　標題(Na)　[(PARENTHESISCATEGORY)　問卦(Na)　] (FW)　還(D)　在(P)　關心(VK)　餵(VC)　藥案(Na)　的(DE)　是(SHI)　哪(Nep)　種(Nf)　人(Na)　？(QUESTIONCATEGORY)　時間(Na)　Tue Jun (FW)　27(Neu)　 (WHITESPACE)　14:50:14(Nd)　 (WHITESPACE)　2023
# (Nd)　剛剛(D)　滑臉書(Na)　看到(VE)　有些(Neqa)　人(Na)　說(VE)　厭倦(VJ)　me too(FW)　了(T)
#
# (WHITESPACE)　真正(D)　要(D)　關心(VK)　的(DE)　是(SHI)　新(VH)　北(Ncd)　餵(VC)　藥案(Na)　 (WHITESPACE)　沒有(VJ)　烏龍(Na)　這(Nep)　種(Nf)　事(Na)
#
# (WHITESPACE)　不(D)　是(SHI)　都(D)　被(P)　證實(VE)　是(SHI)　假(VH)　消息(Na)　了(T)　嗎(T)　？(QUESTIONCATEGORY)
#
# (WHITESPACE)　有(V_2)　沒(D)　有(V_2)　這些(Neqa)　人(Na)　的(DE)　掛？
# ----
# Sent from BePTT on my iPhone 14 Pro Max
#
# --
# (Na)
# (2, 13, 'PERSON', 'bingogobin ')
#
# '作者qazxc1156892 (QQ)看板Gossiping標題[新聞] 端午前才剛出院！桃園女遭親兒勒斃　他時間Tue Jun 27 14:49:54 2023
# ETtoday新聞雲  2023年06月27日 14:30
#
# 端午前才剛出院！桃園女遭親兒勒斃　他伴屍7小時打電話自首
#
# 記者沈繼昌、陳韻如／桃園報導
#
# 桃園市蘆竹區驚傳人倫悲劇！一名張姓婦人長期飽受病痛之苦，動過多次脊椎受術，端午
# 節前也才剛手術出院返家，但沒想到26日上午9點多卻遭到兒子勒斃，其兒子伴屍7個小時
# ，才主動打電話自首。不過等到救護人員趕抵現場時，張婦早已屍僵，全案目前正由檢方
# 偵辦當中。
#
# 據了解，張婦平時與兒子同住，平時生活起居都是張婦在張羅，而其長期飽受脊椎問題所
# 苦，但又不捨花錢，治療也都選擇健保給付，但多次手術後，復原狀況卻不理想，走路也
# 相當緩慢，端午節前也才剛手術出院不久，沒想到卻遭到兒子勒斃。
# 鄰居表示，昨天上午約11時許有看見張婦兒子一副有心事的樣子在屋外四處張望，他上前
# 詢問後，對方僅回應，「想打電話」，但之後不了了之，到了下午才又聽說張婦兒子有請
# 其他鄰居協助報案，但遭到拒絕，一直到下午4點多，警消人員才陸續到場，鄰居們得知
# 消息後也都相當震驚。
#
#
# https://reurl.cc/LAln(FW)　R9
#
#
#
# --
# (Nb)
# (37, 40, 'DATE', '端午前')
# (45, 47, 'GPE', '桃園')
# (94, 105, 'TIME', '2023年06月27日')
# (121, 123, 'GPE', '桃園')
# (133, 136, 'TIME', '7小時')
# (145, 148, 'PERSON', '沈繼昌')
# (149, 152, 'PERSON', '陳韻如')
# (153, 155, 'GPE', '桃園')
# (159, 165, 'GPE', '桃園市蘆竹區')
# (172, 173, 'CARDINAL', '一')
# (174, 175, 'PERSON', '張')
# (215, 223, 'TIME', '26日上午9點多')
# (236, 237, 'CARDINAL', '7')
# (292, 293, 'PERSON', '張')
# (310, 311, 'PERSON', '張')
# (373, 377, 'DATE', '端午節前')
# (404, 406, 'DATE', '昨天')
# (406, 412, 'TIME', '上午約11時')
# (416, 418, 'PERSON', '張婦')
# (467, 469, 'TIME', '下午')
# (473, 474, 'PERSON', '張')
# (498, 503, 'TIME', '下午4點多')
# (546, 547, 'PERSON', '張')
#
# '作者Darvish903 (頭髮捲慘了)看板Gossiping標題[問卦] 月底剩一千撐得到統一獅封王優惠嗎？時間Tue Jun 27 14:49:50 2023
# 欸欸 4窩肥ㄦ喇
#
# 本肥ㄦ的朋友喇
#
# 端午節四天連假
#
# 不小心錢花太兇
#
# 現在戶頭剩一千
#
# 還要撐到下個月
#
# 十號才能領薪水
#
# 聽說統一快封王
#
# 最快這禮拜達成
#
# 現在把錢省著用
#
# 等統一封王優惠
#
# 一次買齊補給品
#
# 有沒有點搞頭啊
#
# 呱呱
#
# --
# 小天使1
# https://i.imgur.com/0umag1y.jpg
# 小天使2
# https://i.imgur.com/Xrv14Bd.jpg
# 小天使3
# https://i.imgur.com/jwxIMf5.jpg
#
# --
# '
# 作者(Na)　Darvish(FW)　903(Neu)　 (WHITESPACE)　((PARENTHESISCATEGORY)　頭髮(Na)　捲慘(VH)　了(T)　)(PARENTHESISCATEGORY)　看板(Na)　Gossiping(FW)　標題(Na)　[(PARENTHESISCATEGORY)　問卦(Na)　] (FW)　月底(Nd)　剩(VJ)　一千(Neu)　撐(VC)　得到(VJ)　統一獅(Nb)　封王(VA)　優惠(VJ)　嗎(T)　？(QUESTIONCATEGORY)　時間(Na)　Tue Jun (FW)　27(Neu)　 (WHITESPACE)　14:49:50(Nd)　 (WHITESPACE)　2023
# (Nd)　欸(I)　欸(I)　 4(FW)　窩肥(Nb)　ㄦ喇
#
# (FW)　本(Nes)　肥ㄦ(VH)　的(DE)　朋友(Na)　喇
#
# (Nb)　端午節(Nd)　四(Neu)　天(Nf)　連(Cbb)　假
#
# (Na)　不(D)　小心(VK)　錢(Na)　花(VC)　太(Dfa)　兇(VH)
#
# (WHITESPACE)　現在(Nd)　戶頭(Na)　剩(VJ)　一千(Neu)
#
# (WHITESPACE)　還要(Dfa)　撐(VC)　到(P)　下(Nes)　個(Nf)　月(Na)
#
# (WHITESPACE)　十號(Nc)　才(D)　能(D)　領(VC)　薪水(Na)
#
# (WHITESPACE)　聽說(VE)　統一(VHC)　快(D)　封(VC)　王
#
# (Na)　最(Dfa)　快(VH)　這(Nep)　禮拜(Na)　達成(VC)
#
# (WHITESPACE)　現在(Nd)　把(P)　錢(Na)　省(VJ)　著(Di)　用(VC)
#
# (WHITESPACE)　等(Cab)　統一(VHC)　封(VC)　王優惠
#
# (Nb)　一(Neu)　次(Nf)　買齊(VC)　補給品(Na)
#
# (WHITESPACE)　有(V_2)　沒有(VJ)　點(Nf)　搞頭(Na)　啊(T)
#
# 呱呱
#
# --
# (FW)　小(VH)　天使(Na)　1
# https://i.imgur.com/0umag1y.jpg
# (Neu)　小(VH)　天使(Na)　2
# https://i.imgur.com/Xrv14Bd.jpg
# (Neu)　小(VH)　天使(Na)　3
# https://i.imgur.com/jwxIMf5.jpg
#
# --
# (Nb)
# (38, 40, 'DATE', '月底')
# (41, 43, 'CARDINAL', '一千')
# (46, 49, 'ORG', '統一獅')
#
# '作者jiern (jiern)看板Gossiping標題[問卦] 這張陳建州合照 是不是快要全中槍時間Tue Jun 27 14:49:11 2023
# https://upload.cc/i1/2023/06/27/xzwPZA.jpg
#
# 這張當年陳建州 徐若瑄 王力宏等人一起聚餐合照的照片
# 傳出感情狀況
# 若瑄 力宏已中槍
# 如今換建州
#
# 這張合照的命中率有沒有100%
#
# --
# '
# 作者(Na)　jiern (FW)　((PARENTHESISCATEGORY)　jiern(FW)　)(PARENTHESISCATEGORY)　看板(Na)　Gossiping(FW)　標題(Na)　[(PARENTHESISCATEGORY)　問卦(Na)　] (FW)　這(Nep)　張(Nf)　陳建州(Nb)　合照(VA)　 (WHITESPACE)　是(SHI)　不(D)　是(SHI)　快要(D)　全(Neqa)　中槍(VH)　時間(Na)　Tue Jun 27 (FW)　14:49:11(Nd)　 (WHITESPACE)　2023
# https://upload.cc/i1/2023/06/27/xzw(Nd)　PZA(FW)　.jpg
#
# (FW)　這(Nep)　張(Nf)　當年(Nd)　陳建州(Nb)　 (WHITESPACE)　徐若瑄(Nb)　 (WHITESPACE)　王力宏(Nb)　等(Cab)　人(Na)　一起(D)　聚餐(VA)　合照(VA)　的(DE)　照片
# (Na)　傳出(VC)　感情(Na)　狀況(Na)
# 若瑄(Na)　 (WHITESPACE)　力宏(Nb)　已(D)　中(VJ)　槍
# (Na)　如今(Nd)　換(VC)　建(VC)　州(Nc)
#
# (WHITESPACE)　這(Nep)　張(Nf)　合照(Na)　的(DE)　命中率(Na)　有(V_2)　沒有(VJ)　100%(Neqa)
#
# --
# (FW)
# (2, 8, 'PERSON', 'jiern ')
# (9, 14, 'PERSON', 'jiern')
# (35, 38, 'PERSON', '陳建州')
# (122, 124, 'DATE', '當年')
# (124, 127, 'PERSON', '陳建州')
# (128, 131, 'PERSON', '徐若瑄')
# (132, 135, 'PERSON', '王力宏')
#
# '作者meblessme (人身攻擊是爛人)看板Gossiping標題Re: [問卦] 為什麼韓國metoo不盛行?時間Tue Jun 27 14:48:58 2023
# 人家都直接拍復仇劇了
# 一個個的魔女
# 忍辱負重，等候多年
# 一朝爆發
# 全家死光
#
# 人家的標準已經變這樣了
# 其他一些國家也開始拍這種劇了
#
# --
# '
# 作者(Na)　meblessme (FW)　((PARENTHESISCATEGORY)　人身攻擊(VB)　是(SHI)　爛人(Na)　)(PARENTHESISCATEGORY)　看板(Na)　Gossiping(FW)　標題(Na)　Re: [(FW)　問(VE)　卦(Na)　] (FW)　為什麼(D)　韓國(Nc)　metoo(FW)　不(D)　盛行(VK)　?(QUESTIONCATEGORY)　時間(Na)　Tue Jun (FW)　27(Neu)　 (WHITESPACE)　14:48:58(Nd)　 (WHITESPACE)　2023
# (Nd)　人家(Nh)　都(D)　直接(VH)　拍復(VC)　仇劇(VA)　了(Di)
# (WHITESPACE)　一個個(Neqa)　的(DE)　魔女(Na)
# (WHITESPACE)　忍辱負重(VH)　，(COMMACATEGORY)　等候(VK)　多(Neqa)　年(Nf)
# (WHITESPACE)　一朝(D)　爆發(VJ)
# (WHITESPACE)　全家(Na)　死光
#
# (Nb)　人家(Nh)　的(DE)　標準(Na)　已經(D)　變(VG)　這樣(VH)　了
# (VH)　其他(Neqa)　一些(Neqa)　國家(Na)　也(D)　開始(VL)　拍(VC)　這(Nep)　種(Nf)　劇(Na)　了(T)
#
# --
# (FW)
# (46, 48, 'GPE', '韓國')
#
# '作者s66449 (老實樣)看板Gossiping標題[問卦] 肥宅溫柔體貼有加分嗎？時間Tue Jun 27 14:48:54 2023
# 如果肥宅是個溫柔體貼的好男人
#
# 對女朋友又很好 也會做貼心的舉動o’_’o
#
#
#
#
# 這種肥宅有加分嗎？
#
#
#
# --
# '
# 作者(Na)　s(FW)　66449(Neu)　 (WHITESPACE)　((PARENTHESISCATEGORY)　老實樣(Na)　)(PARENTHESISCATEGORY)　看板(Na)　Gossiping(FW)　標題(Na)　[(PARENTHESISCATEGORY)　問卦(Na)　] (FW)　肥宅(Na)　溫柔(VH)　體貼(VJ)　有(D)　加分(VB)　嗎(T)　？(QUESTIONCATEGORY)　時間(Na)　Tue Jun (FW)　27(Neu)　 (WHITESPACE)　14:48:54(Nd)　 (WHITESPACE)　2023
# (Nd)　如果(Cbb)　肥宅(Na)　是(SHI)　個(Nf)　溫柔(VH)　體貼(VJ)　的(DE)　好(VH)　男人(Na)
#
# (WHITESPACE)　對(P)　女朋友(Na)　又(D)　很(Dfa)　好(VH)　 (WHITESPACE)　也(D)　會(D)　做(VC)　貼心(VH)　的(DE)　舉動(Na)　o’_’o
#
#
#
#
# (FW)　這(Nep)　種(Nf)　肥宅(Na)　有(V_2)　加分(VB)　嗎(T)　？(QUESTIONCATEGORY)
#
#
#
# --
# (FW)
#
# '作者AGIknight (炸刑事警察局是不行滴)看板Gossiping標題[問卦] 黑人的性能力很好的八卦?時間Tue Jun 27 14:48:06 2023
#
# 如題
#
# 我聽說黑人的性能力很好
#
# 台女用了都哇哇叫
#
#
#
# 三種人種裡面
#
# 黑人最智障但是老二最大
#
# 白人腦子中等，老二中等
#
# 黃種人腦子最聰明，但是老二根爛掉一樣
#
#
# 黑人的到底有多大根
#
# 有NONO的大根嗎
#
# 該不會NONO其實就是黑人
#
# 我沒有看過NONO跟其他黑人同台過
#
# 有八卦嗎?
#
# --
#  職業: 騎士     等級: LV 87
#  ◢ ◣    STR: 76+8     DEX: 30+5
#  ◣◤╫◥◢ AGI: 99+21    INT: 1
#  ◤▌ ▌◥ VIT: 9        LUK: 1
#   ◣█◤
#  ◢◢▃◣◣ 我不是智缺好嗎! 我只是沒點INT!
#
# --
# '
# 作者(Na)　AGIknight (FW)　((PARENTHESISCATEGORY)　炸(VC)　刑事(Na)　警察局(Nc)　是(SHI)　不行(VH)　滴(VC)　)(PARENTHESISCATEGORY)　看板(Na)　Gossiping(FW)　標題(Na)　[(PARENTHESISCATEGORY)　問(VE)　卦(Na)　] (FW)　黑人(Na)　的(DE)　性能力(Na)　很(Dfa)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-01d417433ab9> in <cell line: 8>()
#       9     print()
#      10     print(f"'{sentence}'")
# ---> 11     print_word_pos_sentence(word_sentence_list[i],  pos_sentence_list[i])
#      12     for entity in sorted(entity_sentence_list[i]):
#      13         print(entity)
#
# <ipython-input-13-01d417433ab9> in print_word_pos_sentence(word_sentence, pos_sentence)
#       2     assert len(word_sentence) == len(pos_sentence)
#       3     for word, pos in zip(word_sentence, pos_sentence):
# ----> 4         print(f"{word}({pos})", end="\u3000")
#       5     print()
#       6     return
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/iostream.py in write(self, string)
#     400             is_child = (not self._is_master_process())
#     401             # only touch the buffer in the IO thread to avoid races
# --> 402             self.pub_thread.schedule(lambda : self._buffer.write(string))
#     403             if is_child:
#     404                 # mp.Pool cannot be trusted to flush promptly (or ever),
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/iostream.py in schedule(self, f)
#     201             self._events.append(f)
#     202             # wake event thread (message content is ignored)
# --> 203             self._event_pipe.send(b'')
#     204         else:
#     205             f()
#
# /usr/local/lib/python3.10/dist-packages/zmq/sugar/socket.py in send(self, data, flags, copy, track, routing_id, group)
#     616                 )
#     617             data.group = group
# --> 618         return super().send(data, flags=flags, copy=copy, track=track)
#     619
#     620     def send_multipart(
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._send_copy()
#
# /usr/local/lib/python3.10/dist-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:

# %%
import pandas as pd

count_list = []
# count_dict = {}
for e in entity_sentence_list:
    for i in e:
#         count_dict[i[3]] = count_dict.get(i[3], 0) + 1
#         df = pd.concat([df, pd.DataFrame(i[3])])
        if i[2] != 'DATE' and i[2] != 'CARDINAL' :
          count_list.append(i[3])

# %%
df = pd.DataFrame(count_list, columns=["entity"])
text = df.entity.value_counts()
text.head(30)
# Out:
# 陳建州       123
# 台灣        112
# 范瑋琪        41
# 中國         41
# 范范         33
# 美國         25
# 香港         24
# 民進黨        23
# 賴清德        22
# 日本         22
# 第一         19
# 陳凱凌        19
# 台北         19
# 台南         18
# 周宜霈        17
# 華航         14
# 侯友宜        13
# 賴          12
# 周幼婷        12
# 陳          11
# Jordan     11
# 國民黨        10
# 鄭文燦        10
# 教育部         9
# 第二          9
# 張           9
# 我愛黑澀會       9
# 台           8
# 安博          8
# 安伯赫德        8
# Name: entity, dtype: int64

# %%
# from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
# import matplotlib.pyplot as plt

# !wget "https://noto-website-2.storage.googleapis.com/pkgs/NotoSansCJKtc-hinted.zip"
# !unzip "NotoSansCJKtc-hinted.zip"

# text = " ".join(review for review in count_list)
# # back_color = imageio.imread("./taiwan.png")
# wordcloud = WordCloud(width=1200, height=600, max_font_size=200, max_words=200, background_color="black",
#                       font_path='NotoSansCJKtc-Regular.otf', colormap="Dark2").generate(text)
# plt.figure(dpi=600)
# plt.imshow(wordcloud)
# plt.axis("off")
# plt.show()

# %%
# !pip install openai

import openai

openai.api_key = "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"
openai.organization = "org-0Sht4Hu0C0AxYGig8vayIx7T"
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting openai
#   Downloading openai-0.27.8-py3-none-any.whl (73 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.6/73.6 kB 7.3 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.10/dist-packages (from openai) (2.27.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from openai) (4.65.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from openai) (3.8.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai) (2023.5.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai) (3.4)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai) (1.3.1)
# Installing collected packages: openai
# Successfully installed openai-0.27.8

# %%
def sentiment_prompt_chinese(chat):
    return f'''
    在一組"<>"中是一篇發文，請對這篇文章進行情緒分析。
    Your answer is a single word, either "positive" or "negative" or "neutral".

    Provide above sentiment result and stock target answers in JSON format with keys, respectively:
    sentiment.
    And Follow the format:

    {{"sentiment":...}}

    chat text: <{chat}>
    '''

def get_completion(prompt, model="gpt-3.5-turbo"):

    # prompt = sentiment_prompt(prompt)
    messages = [{"role": "user", "content": prompt}]
    if model == "gpt-3.5-turbo":
        response = openai.ChatCompletion.create(
            model=model,
            messages=messages,
            temperature=0
        )
        return response.choices[0].message["content"]
    else:
        response = openai.Completion.create(
            model="text-davinci-003",
            prompt=prompt
        )
    return response.choices[0].text

# %%
for i in df0626.Content:
# Out:
# 0      作者Mazda6680 (SEALs)看板Gossiping標題Re: [問卦] 服貿有什麼...
# 1      作者askaleroux (Falcon)看板Gossiping標題[問卦] 簡體字的簡化邏...
# 2      作者alexf1027 (洪興毒蛇浩南哥)看板Gossiping標題[問卦] 只有考拉吃桉樹...
# 3      作者sangi (山雞)看板Gossiping標題[問卦] 誰還沒翻車讓你意外？時間Tue ...
# 4      作者mHRUed (魯魯咪的魯蛇)看板Gossiping標題[問卦] 大家會羨慕黑人哥嗎?時...
#                              ...
# 295    作者Carmelo (Melo)看板Gossiping標題[新聞] 黑人才叫楊敬敏「珍惜舞台...
# 296    作者mowkow0611 (威爺)看板Gossiping標題[問卦] 聖人模式有多重要?時間...
# 297    作者missingkid ()看板Gossiping標題[問卦] 台籃P+的P是什麼P時間T...
# 298    作者casper955033 (Casper)看板Gossiping標題Re: [問卦] 黑...
# 299    作者nissan168 (pingGO)看板Gossiping標題[問卦] 想紅得上床，那已...
# Name: Content, Length: 300, dtype: object
